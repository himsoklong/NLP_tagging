# %%
import os
import pandas as pd
import fnmatch
from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import pipeline
#pip install keybert

# %% [markdown]
# ## Functions

# %%
#function that gets tokens from files
def tokens_from_files(directory, pattern='*.final'):
    """
    Recursively find all files matching the pattern,calls another function to extract tokens
    Input: path to directory (string) 
    Returns: list of tokens """
    
    file_path_list = []
    for root, dirnames, filenames in os.walk(directory):
        for filename in fnmatch.filter(filenames, pattern):
            file_path_list.append(os.path.join(root, filename))

    token_label_list=_extract_tokens(file_path_list)
    return token_label_list

def _extract_tokens(file_list):
    """
    Extracts tokens from a list of files
    Input: list of file names 
    Returns: list of tokens """
    
    token_label_list = []
    for file in file_list:
        with open(file,'r',errors='replace') as f:
             for token_label in f.read().splitlines():
                token_label_list.append(token_label)
    return token_label_list

#Function that takes a list of tokens, cleans it and outputs dataframe
def deep_clean(str_list):
    '''
    Cleans data and converts list of tokens to dataframe
    Input: list of tokens
    Returns: dataframe with columns 'Token' and 'Label' '''
    
    str_list = list(filter(str.strip, str_list)) #remove empty lines
    last_label='' #variable that keeps track of the label of the previous row
    df = pd.DataFrame(columns = ["Token", "Label"]) #creating an empty dataframe with two columns

    for line in str_list:
        line="".join(line.rstrip().lstrip()) #removes spaces on the left and right of each line
        if line[-1]=='I' and last_label in'Oo': #checks that no 'I' labels are preceded by an'O'
            line = list(line)
            line[-1] = 'B'  #if the condition is true, the 'I' is replaced by a 'B'
            line=''.join(line)
        if line[-1]=='0': #if the label is annotated as '0' it is changed to 'O'
            line = list(line)
            line[-1] = 'O'
            line=''.join(line)
        if line[-2:]=='II': #if the label is annotated as 'II' it is changed to 'I'
            line = list(line)
            line[-2:] = 'I'
            line=''.join(line)
        if line[-1] in 'OBIobi': #make sure all labels are either 'O' 'I' or 'B'
            try:
                row=line.split() #split by space or tab
                df.loc[len(df)] = row #add row to dataframe
            except ValueError:
                pass #skip problematic lines
            df['Label'] = df['Label'].str.upper() #make all labels upper case
        last_label=line[-1] #updates label of previous row for next loop
    return df
def df_to_text(df):
    '''
    Converts dataframe of tokens to text
    Input: dataframe
    Returns: string'''
    
    data_csv = df['Token'].to_csv(header=None, index=False).split('\n')
    text_from_df = ' '.join(data_csv)
    return text_from_df

def normalize_model_tag(label):
    '''Normalizes tags on model data
       Input: tag, dtype: string
       Output: tag, dtype: string'''
    
    map_dict = {'B-ORG':'B','B-LOC':'B','B-PER':'B','B-MISC':'MISC', 
                  'I-ORG':'ORG','I-LOC':'LOC','I-PER':'PER','I-MISC':'MISC'}
    replace_if_need = lambda entity: map_dict.get(entity,entity) #if the tag is in the dict, give its replacement, otherwise keep it 
    label['entity'] = replace_if_need(label['entity'])
    return label

# %% [markdown]
# ### Main

# %%
# Note: This cell takes a long time to execute

path='../Dataset/' #add your directory path

str_list = tokens_from_files(path) #find final annotation files in directory and extract tokens
df=deep_clean(str_list) #create dataframe with tokens and labels (and remove/correct erroneous lines)

# %%
str_list = tokens_from_files(path+'train') #find final annotation files in directory and extract tokens
df_train=deep_clean(str_list) #create dataframe with tokens and labels (and remove/correct erroneous lines)

# %%
str_list = tokens_from_files(path+'test') #find final annotation files in directory and extract tokens
df_test=deep_clean(str_list) #create dataframe with tokens and labels (and remove/correct erroneous lines)

# %%
df
# Out:
#                 Token Label
# 0         Translation     B
# 1              models     I
# 2                used     O
# 3                 for     O
# 4         statistical     B
# ...               ...   ...
# 26660          mutual     O
# 26661  disambiguation     B
# 26662             and     O
# 26663  generalization     B
# 26664               .     O
#
# [26665 rows x 2 columns]

# %%
text=df_to_text(df)

# %%
text
# Out:
# 'Translation models used for statistical machine translation are compiled from parallel corpora that are manually translated . The common assumption is that parallel texts are symmetrical : The direction of translation is deemed irrelevant and is consequently ignored . Much research in Translation Studies indicates that the direction of translation matters "," however "," as translated language ( translationese ) has many unique properties . It has already been shown that phrase tables constructed from parallel corpora translated in the same direction as the translation task outperform those constructed from corpora translated in the opposite direction . We reconfirm that this is indeed the case "," but emphasize the importance of also using texts translated in the “ wrong ” direction . We take advantage of information pertaining to the direction of translation in constructing phrase tables by adapting the translation model to the special properties of translationese . We explore two adaptation techniques : First "," we create a mixture model by interpolating phrase tables trained on texts translated in the “ right ” and the “ wrong ” directions . The weights for the interpolation are determined by minimizing perplexity . Second "," we define entropy - based measures that estimate the correspondence of target - language phrases to translationese "," thereby eliminating the need to annotate the parallel corpus with information pertaining to the direction of translation . We show that incorporating these measures as features in the phrase tables of statistical machine translation systems results in consistent "," statistically significant improvement in the quality of the translation . As more and more Arabic textual information becomes available through the Web in homes and businesses "," via Internet and Intranet services "," there is an urgent need for technologies and tools to process the relevant information . Named Entity Recognition ( NER ) is an Information Extraction task that has become an integral part of many other Natural Language Processing ( NLP ) tasks "," such as Machine Translation and Information Retrieval . Arabic NER has begun to receive attention in recent years . The characteristics and peculiarities of Arabic "," a member of the Semitic languages family "," make dealing with NER a challenge . The performance of an Arabic NER component affects the overall performance of the NLP system in a positive manner . This article attempts to describe and detail the recent increase in interest and progress made in Arabic NER research . The importance of the NER task is demonstrated "," the main characteristics of the Arabic language are highlighted "," and the aspects of standardization in annotating named entities are illustrated . Moreover "," the different Arabic linguistic resources are presented and the approaches used in Arabic NER field are explained . The features of common tools used in Arabic NER are described "," and standard evaluation metrics are illustrated . In addition "," a review of the state of the art of Arabic NER research is discussed . Finally "," we present our conclusions . Throughout the presentation "," illustrative examples are used for clarification . We present a statistical parsing framework for sentence - level sentiment classification in this article . Unlike previous works that use syntactic parsing results for sentiment analysis "," we develop a statistical parser to directly analyze the sentiment structure of a sentence . We show that complicated phenomena in sentiment analysis ( e.g. "," negation "," intensification "," and contrast ) can be handled the same way as simple and straightforward sentiment expressions in a unified and probabilistic way . We formulate the sentiment grammar upon Context - Free Grammars ( CFGs ) "," and provide a formal description of the sentiment parsing framework . We develop the parsing model to obtain possible sentiment parse trees for a sentence "," ...

# %% [markdown]
# ## Comparison with KeyBERT

# %%
from keybert import KeyBERT
kw_model = KeyBERT(model="all-MiniLM-L6-v2")

#kw_model.extract_keywords(doc, keyphrase_ngram_range=(3, 3), stop_words='english', use_maxsum=True, nr_candidates=20, top_n=5)
# Out:
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
kw_model.extract_keywords(text, keyphrase_ngram_range=(1, 4), stop_words='english', top_n=200)
# Out:
# [('phrase tables adapting translation', 0.7342),
#  ('tables statistical machine translation', 0.6856),
#  ('translation constructing phrase tables', 0.6739),
#  ('statistical machine translation specifically', 0.6675),
#  ('tables adapting translation model', 0.6642),
#  ('various statistical machine translation', 0.6628),
#  ('tables adapting translation', 0.6601),
#  ('statistical machine translation models', 0.6562),
#  ('statistical machine translation', 0.6562),
#  ('machine translation attempts', 0.6346),
#  ('statistical machine translation model', 0.6344),
#  ('current machine translation', 0.633),
#  ('statistical machine translation actually', 0.6293),
#  ('adapting translation model', 0.6291),
#  ('translation models used statistical', 0.6255),
#  ('machine translation information', 0.6202),
#  ('techniques statistical machine translation', 0.6197),
#  ('various existing machine translation', 0.619),
#  ('traditional statistical machine translation', 0.6178),
#  ('improved statistical machine translation', 0.6178),
#  ('machine translation models', 0.6175),
#  ('machine translation relative', 0.6166),
#  ('machine translation actually related', 0.6149),
#  ('existing machine translation', 0.6128),
#  ('english machine translation relative', 0.6086),
#  ('adapting translation', 0.6084),
#  ('word translation task parallel', 0.6075),
#  ('machine translation specifically', 0.6054),
#  ('machine translation', 0.6053),
#  ('adapting translation model special', 0.6051),
#  ('used statistical machine translation', 0.6047),
#  ('translation models', 0.6014),
#  ('machine translation transfer', 0.6008),
#  ('constructing phrase tables adapting', 0.6003),
#  ('statistical machine translation systems', 0.6002),
#  ('linguistic knowledge distribution translation', 0.5996),
#  ('phrase tables adapting', 0.5989),
#  ('machine translation model', 0.5986),
#  ('poor statistical machine translation', 0.5984),
#  ('including machine translation information', 0.5977),
#  ('translation modeling', 0.5973),
#  ('novel machine translation model', 0.5935),
#  ('quality statistical machine translation', 0.5927),
#  ('existing machine translation evaluation', 0.5899),
#  ('statistical machine translation output', 0.5898),
#  ('associated word translation task', 0.5896),
#  ('target language phrases translationese', 0.5891),
#  ('machine translation scenarios', 0.5873),
#  ('statistical machine translation compiled', 0.5864),
#  ('based statistical machine translation', 0.5864),
#  ('computer assisted translation model', 0.5853),
#  ('machine translation model operation', 0.5853),
#  ('machine translation present', 0.5843),
#  ('machine translation systems results', 0.5821),
#  ('building machine translation', 0.5819),
#  ('computer assisted translation', 0.5801),
#  ('parallel corpora manually translated', 0.58),
#  ('machine translation output computationally', 0.5798),
#  ('machine translation information retrieval', 0.5777),
#  ('machine translation evaluation metrics', 0.5762),
#  ('processing including machine translation', 0.5761),
#  ('translation modeling flexibility', 0.576),
#  ('english machine translation', 0.5758),
#  ('translation divergences semantic representations', 0.5753),
#  ('novel machine translation', 0.5753),
#  ('translation performance various statistical', 0.5752),
#  ('machine translation attempts replicate', 0.5742),
#  ('translation information retrieval', 0.5726),
#  ('assisted translation model', 0.5714),
#  ('transfer based machine translation', 0.5701),
#  ('corpora translated direction translation', 0.5692),
#  ('translation systems results', 0.5691),
#  ('optimal extracting translation', 0.5691),
#  ('present novel machine translation', 0.567),
#  ('machine translation evaluation particular', 0.5669),
#  ('machine translation evaluation', 0.5666),
#  ('optimal extracting translation rules', 0.5662),
#  ('nlp tasks machine translation', 0.5634),
#  ('machine translation model multiple', 0.5633),
#  ('translation models used', 0.5632),
#  ('unsupervised word translation', 0.5631),
#  ('translation tasks translation', 0.5626),
#  ('translation task outperform constructed', 0.5619),
#  ('neural machine translation', 0.5617),
#  ('embeddings associated word translation', 0.5616),
#  ('including machine translation', 0.5614),
#  ('tasks machine translation information', 0.5612),
#  ('corpora manually translated', 0.561),
#  ('lexicalized reordering translation tasks', 0.5594),
#  ('machine translation provide useful', 0.559),
#  ('unsupervised word translation propose', 0.559),
#  ('tables trained texts translated', 0.5586),
#  ('statistical language models', 0.5585),
#  ('machine translation specifically build', 0.5583),
#  ('classify translation', 0.5582),
#  ('captures possible translation', 0.5574),
#  ('machine translation systems generating', 0.5571),
#  ('machine translation models resource', 0.557),
#  ('assisted translation model entails', 0.5565),
#  ('machine translation provide', 0.556),
#  ('resource poor machine translation', 0.5558),
#  ('statistical language modeling', 0.5558),
#  ('bilingual corpora generative models', 0.5545),
#  ('translation systems generating', 0.5537),
#  ('machine translation systems', 0.5518),
#  ('tasks machine translation', 0.5507),
#  ('translation tasks', 0.5505),
#  ('semantic representations translation divergences', 0.5492),
#  ('machine translation written', 0.5488),
#  ('outperforms lexicalized reordering translation', 0.5482),
#  ('translation report statistically', 0.5474),
#  ('machine translation relative traditional', 0.5465),
#  ('improves translation performance', 0.5459),
#  ('translation tasks translation quality', 0.5451),
#  ('corpora translated direction', 0.5447),
#  ('translation transfer learning', 0.544),
#  ('translation modeling flexibility proved', 0.5438),
#  ('word translation task', 0.5437),
#  ('machine translation discuss', 0.5436),
#  ('translation divergences semantic', 0.5434),
#  ('assisted translation', 0.5427),
#  ('associated word translation', 0.5424),
#  ('translation compiled parallel corpora', 0.5423),
#  ('current machine translation mt', 0.5422),
#  ('statistical machine translation smt', 0.5415),
#  ('summarization machine translation attempts', 0.5413),
#  ('captures possible translation divergences', 0.5404),
#  ('statistical language models including', 0.5403),
#  ('language translations experimental', 0.54),
#  ('machine translation output', 0.54),
#  ('data yield substantial translation', 0.5396),
#  ('translation systems', 0.5393),
#  ('approach improves translation performance', 0.539),
#  ('parsing machine translation', 0.5384),
#  ('direction translation constructing phrase', 0.5383),
#  ('based translation report statistically', 0.5378),
#  ('translation information', 0.5372),
#  ('translation task parallel', 0.537),
#  ('translation evaluation metrics', 0.5367),
#  ('translated direction translation task', 0.5362),
#  ('models statistical language models', 0.5354),
#  ('translation model', 0.5353),
#  ('translation constructing phrase', 0.5352),
#  ('knowledge order classify translation', 0.5352),
#  ('language translations experimental results', 0.535),
#  ('large bilingual corpora generative', 0.5344),
#  ('large translation units search', 0.5343),
#  ('translation tasks compare', 0.5342),
#  ('translation systems generating responses', 0.5341),
#  ('machine translation transfer learning', 0.5336),
#  ('people building machine translation', 0.5322),
#  ('language translations', 0.5319),
#  ('machine translation discuss general', 0.5314),
#  ('phrase tables statistical machine', 0.5312),
#  ('translation systems results consistent', 0.5311),
#  ('different translation systems', 0.5309),
#  ('reordering translation tasks translation', 0.5308),
#  ('correspondence target language phrases', 0.5306),
#  ('taken statistical language models', 0.5305),
#  ('substantial translation quality improvements', 0.5299),
#  ('outperform constructed corpora translated', 0.5297),
#  ('bilingual corpora generative', 0.5295),
#  ('standard translation tasks', 0.5291),
#  ('machine translation compiled parallel', 0.5289),
#  ('translation task outperform', 0.5285),
#  ('translation models resource', 0.5282),
#  ('assisted translation systems', 0.5282),
#  ('results translation divergences broader', 0.5282),
#  ('machine translation present article', 0.5282),
#  ('machine translation evaluation design', 0.5281),
#  ('direction translation incorporating', 0.528),
#  ('information certain translation', 0.528),
#  ('language phrases translationese', 0.5271),
#  ('interpretation statistical language modeling', 0.5267),
#  ('machine translation inspired', 0.5266),
#  ('translation using large adapted', 0.5265),
#  ('computer assisted translation systems', 0.5265),
#  ('structure machine translation evaluation', 0.5264),
#  ('divergences semantic representations translation', 0.5263),
#  ('translation constructing', 0.526),
#  ('parsing machine translation present', 0.526),
#  ('machine translation mt', 0.5257),
#  ('statistical language models combination', 0.5255),
#  ('translation incorporating measures features', 0.5252),
#  ('categorize translation divergences', 0.5247),
#  ('semantic representations translation', 0.5247),
#  ('languages involved translation directions', 0.5237),
#  ('interpolating phrase tables trained', 0.5235),
#  ('translationese explore adaptation techniques', 0.5233),
#  ('machine translation written form', 0.523),
#  ('syntax based machine translation', 0.5225),
#  ('standard translation tasks compare', 0.5223),
#  ('machine translation map', 0.5221),
#  ('machine translation systems resource', 0.5217),
#  ('data translation', 0.5215),
#  ('translation evaluation metrics regarding', 0.5213),
#  ('fourth machine translation', 0.5212),
#  ('knowledge distribution translation', 0.5207),
#  ('learned neural machine translation', 0.5207),
#  ('machine translation output important', 0.5203)]

# %% [markdown]
# ## CRF

# %%
from itertools import chain

import nltk
import sklearn
import scipy.stats
from sklearn.metrics import make_scorer
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RandomizedSearchCV

import sklearn_crfsuite
from sklearn_crfsuite import scorers
from sklearn_crfsuite import metrics

# %%
def make_sent(df):
    '''Turns every row in the data frame to a tuple. 
    The tuples of one sentence are saved in a list.
    The sentences are saved in a list.
    Input: dataframe
    Returns: list of list of tuples'''
    tuple_list=list(df.itertuples(index=False, name=None))
    stoplist=['.','?','!']
    sent_list=[]
    sent=[]
    for el in tuple_list:
        sent.append(el)
        if el[0] in stoplist:
            sent_list.append(sent)
            sent=[]
    return sent_list

# %%
train_sents=make_sent(df_train)
test_sents=make_sent(df_test)

# %%
train_sents
# Out:
# [[('The', 'O'),
#   ('most', 'O'),
#   ('widely', 'O'),
#   ('adopted', 'O'),
#   ('approaches', 'O'),
#   ('for', 'O'),
#   ('evaluation', 'B'),
#   ('of', 'O'),
#   ('summary', 'B'),
#   ('content', 'I'),
#   ('follow', 'O'),
#   ('some', 'O'),
#   ('protocol', 'O'),
#   ('for', 'O'),
#   ('comparing', 'O'),
#   ('a', 'O'),
#   ('summary', 'O'),
#   ('with', 'O'),
#   ('gold', 'B'),
#   ('-', 'I'),
#   ('standard', 'I'),
#   ('human', 'B'),
#   ('summaries', 'I'),
#   (',', 'O'),
#   ('which', 'O'),
#   ('are', 'O'),
#   ('traditionally', 'O'),
#   ('called', 'O'),
#   ('model', 'B'),
#   ('summaries', 'I'),
#   ('.', 'O')],
#  [('This', 'O'),
#   ('evaluation', 'B'),
#   ('paradigm', 'I'),
#   ('falls', 'O'),
#   ('short', 'O'),
#   ('when', 'O'),
#   ('human', 'B'),
#   ('summaries', 'I'),
#   ('are', 'O'),
#   ('not', 'O'),
#   ('available', 'O'),
#   ('and', 'O'),
#   ('becomes', 'O'),
#   ('less', 'O'),
#   ('accurate', 'O'),
#   ('when', 'O'),
#   ('only', 'O'),
#   ('a', 'O'),
#   ('single', 'O'),
#   ('model', 'B'),
#   ('is', 'O'),
#   ('available', 'O'),
#   ('.', 'O')],
#  [('We', 'O'),
#   ('propose', 'O'),
#   ('three', 'O'),
#   ('novel', 'O'),
#   ('evaluation', 'B'),
#   ('techniques', 'I'),
#   ('.', 'O')],
#  [('Two', 'O'),
#   ('of', 'O'),
#   ('them', 'O'),
#   ('are', 'O'),
#   ('model', 'B'),
#   ('-', 'I'),
#   ('free', 'I'),
#   ('and', 'O'),
#   ('do', 'O'),
#   ('not', 'O'),
#   ('rely', 'O'),
#   ('on', 'O'),
#   ('a', 'O'),
#   ('gold', 'B'),
#   ('standard', 'I'),
#   ('for', 'O'),
#   ('the', 'O'),
#   ('assessment', 'O'),
#   ('.', 'O')],
#  [('The', 'O'),
#   ('third', 'O'),
#   ('technique', 'O'),
#   ('improves', 'O'),
#   ('standard', 'O'),
#   ('automatic', 'B'),
#   ('evaluations', 'I'),
#   ('by', 'O'),
#   ('expanding', 'O'),
#   ('the', 'O'),
#   ('set', 'O'),
#   ('of', 'O'),
#   ('available', 'O'),
#   ('model', 'B'),
#   ('summaries', 'O'),
#   ('with', 'O'),
#   ('chosen', 'O'),
#   ('system', 'O'),
#   ('summaries', 'O'),
#   ('.', 'O')],
#  [('We', 'O'),
#   ('show', 'O'),
#   ('that', 'O'),
#   ('quantifying', 'O'),
#   ('the', 'O'),
#   ('similarity', 'O'),
#   ('between', 'O'),
#   ('the', 'O'),
#   ('source', 'O'),
#   ('text', 'O'),
#   ('and', 'O'),
#   ('its', 'O'),
#   ('summary', 'O'),
#   ('with', 'O'),
#   ('appropriately', 'O'),
#   ('chosen', 'O'),
#   ('measures', 'O'),
#   ('produces', 'O'),
#   ('summary', 'O'),
#   ('scores', 'O'),
#   ('which', 'O'),
#   ('replicate', 'O'),
#   ('human', 'O'),
#   ('assessments', 'O'),
#   ('accurately', 'O'),
#   ('.', 'O')],
#  [('We', 'O'),
#   ('also', 'O'),
#   ('explore', 'O'),
#   ('ways', 'O'),
#   ('of', 'O'),
#   ('increasing', 'O'),
#   ('evaluation', 'B'),
#   ('quality', 'I'),
#   ('when', 'O'),
#   ('only', 'O'),
#   ('one', 'O'),
#   ('human', 'B'),
#   ('model', 'I'),
#   ('summary', 'I'),
#   ('is', 'O'),
#   ('available', 'O'),
#   ('as', 'O'),
#   ('a', 'O'),
#   ('gold', 'B'),
#   ('standard', 'I'),
#   ('.', 'O')],
#  [('We', 'O'),
#   ('introduce', 'O'),
#   ('pseudomodels', 'B'),
#   (',', 'O'),
#   ('which', 'O'),
#   ('are', 'O'),
#   ('system', 'B'),
#   ('summaries', 'I'),
#   ('deemed', 'O'),
#   ('to', 'O'),
#   ('contain', 'O'),
#   ('good', 'O'),
#   ('content', 'O'),
#   ('according', 'O'),
#   ('to', 'O'),
#   ('automatic', 'B'),
#   ('evaluation', 'I'),
#   ('.', 'O')],
#  [('Combining', 'O'),
#   ('the', 'O'),
#   ('pseudomodels', 'B'),
#   ('with', 'O'),
#   ('the', 'O'),
#   ('single', 'B'),
#   ('human', 'I'),
#   ('model', 'I'),
#   ('to', 'O'),
#   ('form', 'O'),
#   ('the', 'O'),
#   ('gold', 'B'),
#   ('-', 'I'),
#   ('standard', 'I'),
#   ('leads', 'O'),
#   ('to', 'O'),
#   ('higher', 'O'),
#   ('correlations', 'B'),
#   ('with', 'O'),
#   ('human', 'O'),
#   ('judgments', 'O'),
#   ('compared', 'O'),
#   ('to', 'O'),
#   ('using', 'O'),
#   ('only', 'O'),
#   ('the', 'O'),
#   ('one', 'O'),
#   ('available', 'O'),
#   ('model', 'B'),
#   ('.', 'O')],
#  [('Finally', 'O'),
#   (',', 'O'),
#   ('we', 'O'),
#   ('explore', 'O'),
#   ('the', 'O'),
#   ('feasibility', 'O'),
#   ('of', 'O'),
#   ('another', 'O'),
#   ('measure', 'B'),
#   ('—', 'I'),
#   ('similarity', 'I'),
#   ('between', 'O'),
#   ('a', 'O'),
#   ('system', 'O'),
#   ('summary', 'O'),
#   ('and', 'O'),
#   ('the', 'O'),
#   ('pool', 'O'),
#   ('of', 'O'),
#   ('all', 'O'),
#   ('other', 'O'),
#   ('system', 'O'),
#   ('summaries', 'O'),
#   ('for', 'O'),
#   ('the', 'O'),
#   ('same', 'O'),
#   ('input', 'O'),
#   ('.', 'O')],
#  [('This', 'O'),
#   ('method', 'O'),
#   ('of', 'O'),
#   ('comparison', 'O'),
#   ('with', 'O'),
#   ('the', 'O'),
#   ('consensus', 'O'),
#   ('of', 'O'),
#   ('systems', 'O'),
#   ('produces', 'O'),
#   ('impressively', 'O'),
#   ('accurate', 'O'),
#   ('rankings', 'O'),
#   ('of', 'O'),
#   ('system', 'O'),
#   ('summaries', 'O'),
#   (',', 'O'),
#   ('achieving', 'O'),
#   ('correlation', 'B'),
#   ('with', 'O'),
#   ('human', 'O'),
#   ('rankings', 'O'),
#   ('above', 'O'),
#   ('0.9', 'O'),
#   ('.', 'O')],
#  [('In', 'O'),
#   ('this', 'O'),
#   ('article', 'O'),
#   (',', 'O'),
#   ('an', 'O'),
#   ('integrated', 'O'),
#   ('model', 'O'),
#   ('is', 'O'),
#   ('derived', 'O'),
#   ('that', 'O'),
#   ('jointly', 'O'),
#   ('identifies', 'O'),
#   ('and', 'O'),
#   ('aligns', 'O'),
#   ('bilingual', 'B'),
#   ('named', 'B'),
#   ('entities', 'I'),
#   ('(', 'O'),
#   ('NEs', 'B'),
#   (')', 'O'),
#   ('between', 'O'),
#   ('Chinese', 'O'),
#   ('and', 'O'),
#   ('English', 'O'),
#   ('.', 'O')],
#  [('The', 'O'),
#   ('model', 'B'),
#   ('is', 'O'),
#   ('motivated', 'O'),
#   ('by', 'O'),
#   ('the', 'O'),
#   ('following', 'O'),
#   ('observations', 'O'),
#   (':', 'O'),
#   ('(', 'O'),
#   ('1', 'O'),
#   (')', 'O'),
#   ('whether', 'O'),
#   ('an', 'O'),
#   ('NE', 'B'),
#   ('is', 'O'),
#   ('translated', 'O'),
#   ('semantically', 'B'),
#   ('or', 'O'),
#   ('phonetically', 'B'),
#   ('depends', 'O'),
#   ('greatly', 'O'),
#   ('on', 'O'),
#   ('its', 'O'),
#   ('entity', 'B'),
#   ('type', 'I'),
#   (',', 'O'),
#   ('(', 'O'),
#   ('2', 'O'),
#   (')', 'O'),
#   ('entities', 'B'),
#   ('within', 'O'),
#   ('an', 'O'),
#   ('aligned', 'B'),
#   ('pair', 'I'),
#   ('should', 'O'),
#   ('share', 'O'),
#   ('the', 'O'),
#   ('same', 'O'),
#   ('type', 'O'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('(', 'O'),
#   ('3', 'O'),
#   (')', 'O'),
#   ('the', 'O'),
#   ('initially', 'O'),
#   ('detected', 'O'),
#   ('NEs', 'B'),
#   ('can', 'O'),
#   ('act', 'O'),
#   ('as', 'O'),
#   ('anchors', 'O'),
#   ('and', 'O'),
#   ('provide', 'O'),
#   ('further', 'O'),
#   ('information', 'O'),
#   ('while', 'O'),
#   ('selecting', 'O'),
#   ('NE', 'B'),
#   ('candidates', 'O'),
#   ('.', 'O')],
#  [('Based', 'O'),
#   ('on', 'O'),
#   ('these', 'O'),
#   ('observations', 'O'),
#   (',', 'O'),
#   ('this', 'O'),
#   ('article', 'O'),
#   ('proposes', 'O'),
#   ('a', 'O'),
#   ('translation', 'O'),
#   ('mode', 'O'),
#   ('ratio', 'O'),
#   ('feature', 'O'),
#   ('(', 'O'),
#   ('defined', 'O'),
#   ('as', 'O'),
#   ('the', 'O'),
#   ('proportion', 'O'),
#   ('of', 'O'),
#   ('NE', 'B'),
#   ('internal', 'O'),
#   ('tokens', 'B'),
#   ('that', 'O'),
#   ('are', 'O'),
#   ('semantically', 'B'),
#   ('translated', 'I'),
#   (')', 'O'),
#   (',', 'O'),
#   ('enforces', 'O'),
#   ('an', 'O'),
#   ('entity', 'B'),
#   ('type', 'I'),
#   ('consistency', 'B'),
#   ('constraint', 'I'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('utilizes', 'O'),
#   ('additional', 'O'),
#   ('new', 'O'),
#   ('NE', 'B'),
#   ('likelihoods', 'B'),
#   ('(', 'O'),
#   ('based', 'O'),
#   ('on', 'O'),
#   ('the', 'O'),
#   ('initially', 'O'),
#   ('detected', 'O'),
#   ('NE', 'B'),
#   ('anchors', 'O'),
#   (')', 'O'),
#   ('.', 'O')],
#  [('Experiments', 'O'),
#   ('show', 'O'),
#   ('that', 'O'),
#   ('this', 'O'),
#   ('novel', 'O'),
#   ('method', 'O'),
#   ('significantly', 'O'),
#   ('outperforms', 'O'),
#   ('the', 'O'),
#   ('baseline', 'B'),
#   ('.', 'O')],
#  [('The', 'O'),
#   ('type', 'B'),
#   ('-', 'I'),
#   ('insensitive', 'I'),
#   ('F', 'B'),
#   ('-', 'I'),
#   ('score', 'I'),
#   ('of', 'O'),
#   ('identified', 'O'),
#   ('NE', 'B'),
#   ('pairs', 'O'),
#   ('increases', 'O'),
#   ('from', 'O'),
#   ('78.4', 'O'),
#   ('%', 'O'),
#   ('to', 'O'),
#   ('88.0', 'O'),
#   ('%', 'O'),
#   ('(', 'O'),
#   ('12.2', 'O'),
#   ('%', 'O'),
#   ('relative', 'O'),
#   ('improvement', 'O'),
#   (')', 'O'),
#   ('in', 'O'),
#   ('our', 'O'),
#   ('Chinese', 'O'),
#   ('–', 'O'),
#   ('English', 'O'),
#   ('NE', 'B'),
#   ('alignment', 'I'),
#   ('task', 'I'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('the', 'O'),
#   ('type', 'B'),
#   ('-', 'I'),
#   ('sensitive', 'I'),
#   ('F', 'B'),
#   ('-', 'I'),
#   ('score', 'I'),
#   ('increases', 'O'),
#   ('from', 'O'),
#   ('68.4', 'O'),
#   ('%', 'O'),
#   ('to', 'O'),
#   ('83.0', 'O'),
#   ('%', 'O'),
#   ('(', 'O'),
#   ('21.3', 'O'),
#   ('%', 'O'),
#   ('relative', 'O'),
#   ('improvement', 'O'),
#   (')', 'O'),
#   ('.', 'O')],
#  [('Furthermore', 'O'),
#   (',', 'O'),
#   ('the', 'O'),
#   ('proposed', 'O'),
#   ('model', 'O'),
#   ('demonstrates', 'O'),
#   ('its', 'O'),
#   ('robustness', 'O'),
#   ('when', 'O'),
#   ('it', 'O'),
#   ('is', 'O'),
#   ('tested', 'O'),
#   ('across', 'O'),
#   ('different', 'O'),
#   ('domains', 'O'),
#   ('.', 'O')],
#  [('Finally', 'O'),
#   (',', 'O'),
#   ('when', 'O'),
#   ('semi', 'B'),
#   ('-', 'I'),
#   ('supervised', 'I'),
#   ('learning', 'I'),
#   ('is', 'O'),
#   ('conducted', 'O'),
#   ('to', 'O'),
#   ('train', 'O'),
#   ('the', 'O'),
#   ('adopted', 'O'),
#   ('English', 'O'),
#   ('NE', 'B'),
#   ('recognition', 'I'),
#   ('model', 'I'),
#   (',', 'O'),
#   ('the', 'O'),
#   ('proposed', 'O'),
#   ('model', 'O'),
#   ('also', 'O'),
#   ('significantly', 'O'),
#   ('boosts', 'O'),
#   ('the', 'O'),
#   ('English', 'O'),
#   ('NE', 'B'),
#   ('recognition', 'I'),
#   ('type', 'B'),
#   ('-', 'I'),
#   ('sensitive', 'I'),
#   ('F', 'B'),
#   ('-', 'I'),
#   ('score', 'I'),
#   ('.', 'O')],
#  [('Knowing', 'O'),
#   ('the', 'O'),
#   ('degree', 'O'),
#   ('of', 'O'),
#   ('semantic', 'B'),
#   ('contrast', 'O'),
#   ('between', 'O'),
#   ('words', 'O'),
#   ('has', 'O'),
#   ('widespread', 'O'),
#   ('application', 'O'),
#   ('in', 'O'),
#   ('natural', 'B'),
#   ('language', 'I'),
#   ('processing', 'I'),
#   (',', 'O'),
#   ('including', 'O'),
#   ('machine', 'B'),
#   ('translation', 'I'),
#   (',', 'O'),
#   ('information', 'B'),
#   ('retrieval', 'I'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('dialogue', 'B'),
#   ('systems', 'I'),
#   ('.', 'O')],
#  [('Manually', 'O'),
#   ('created', 'O'),
#   ('lexicons', 'B'),
#   ('focus', 'O'),
#   ('on', 'O'),
#   ('opposites', 'O'),
#   (',', 'O'),
#   ('such', 'O'),
#   ('as', 'O'),
#   ('hot', 'O'),
#   ('and', 'O'),
#   ('cold', 'O'),
#   ('.', 'O')],
#  [('Opposites', 'O'),
#   ('are', 'O'),
#   ('of', 'O'),
#   ('many', 'O'),
#   ('kinds', 'O'),
#   ('such', 'O'),
#   ('as', 'O'),
#   ('antipodals', 'B'),
#   (',', 'O'),
#   ('complementaries', 'B'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('gradable', 'B'),
#   ('.', 'O')],
#  [('Existing', 'O'),
#   ('lexicons', 'B'),
#   ('often', 'O'),
#   ('do', 'O'),
#   ('not', 'O'),
#   ('classify', 'O'),
#   ('opposites', 'O'),
#   ('into', 'O'),
#   ('the', 'O'),
#   ('different', 'O'),
#   ('kinds', 'O'),
#   (',', 'O'),
#   ('however', 'O'),
#   ('.', 'O')],
#  [('They', 'O'),
#   ('also', 'O'),
#   ('do', 'O'),
#   ('not', 'O'),
#   ('explicitly', 'O'),
#   ('list', 'O'),
#   ('word', 'B'),
#   ('pairs', 'I'),
#   ('that', 'O'),
#   ('are', 'O'),
#   ('not', 'O'),
#   ('opposites', 'O'),
#   ('but', 'O'),
#   ('yet', 'O'),
#   ('have', 'O'),
#   ('some', 'O'),
#   ('degree', 'O'),
#   ('of', 'O'),
#   ('contrast', 'O'),
#   ('in', 'O'),
#   ('meaning', 'O'),
#   (',', 'O'),
#   ('such', 'O'),
#   ('as', 'O'),
#   ('warm', 'O'),
#   ('and', 'O'),
#   ('cold', 'O'),
#   ('or', 'O'),
#   ('tropical', 'O'),
#   ('and', 'O'),
#   ('freezing', 'O'),
#   ('.', 'O')],
#  [('We', 'O'),
#   ('propose', 'O'),
#   ('an', 'O'),
#   ('automatic', 'O'),
#   ('method', 'O'),
#   ('to', 'O'),
#   ('identify', 'O'),
#   ('contrasting', 'O'),
#   ('word', 'B'),
#   ('pairs', 'I'),
#   ('that', 'O'),
#   ('is', 'O'),
#   ('based', 'O'),
#   ('on', 'O'),
#   ('the', 'O'),
#   ('hypothesis', 'O'),
#   ('that', 'O'),
#   ('if', 'O'),
#   ('a', 'O'),
#   ('pair', 'B'),
#   ('of', 'I'),
#   ('words', 'I'),
#   (',', 'O'),
#   ('A', 'O'),
#   ('and', 'O'),
#   ('B', 'O'),
#   (',', 'O'),
#   ('are', 'O'),
#   ('contrasting', 'O'),
#   (',', 'O'),
#   ('then', 'O'),
#   ('there', 'O'),
#   ('is', 'O'),
#   ('a', 'O'),
#   ('pair', 'O'),
#   ('of', 'O'),
#   ('opposites', 'O'),
#   (',', 'O'),
#   ('C', 'O'),
#   ('and', 'O'),
#   ('D', 'O'),
#   (',', 'O'),
#   ('such', 'O'),
#   ('that', 'O'),
#   ('A', 'O'),
#   ('and', 'O'),
#   ('C', 'O'),
#   ('are', 'O'),
#   ('strongly', 'O'),
#   ('related', 'O'),
#   ('and', 'O'),
#   ('B', 'O'),
#   ('and', 'O'),
#   ('D', 'O'),
#   ('are', 'O'),
#   ('strongly', 'O'),
#   ('related', 'O'),
#   ('.', 'O')],
#  [('(', 'O'),
#   ('For', 'O'),
#   ('example', 'O'),
#   (',', 'O'),
#   ('there', 'O'),
#   ('exists', 'O'),
#   ('the', 'O'),
#   ('pair', 'O'),
#   ('of', 'O'),
#   ('opposites', 'O'),
#   ('hot', 'O'),
#   ('and', 'O'),
#   ('cold', 'O'),
#   ('such', 'O'),
#   ('that', 'O'),
#   ('tropical', 'O'),
#   ('is', 'O'),
#   ('related', 'O'),
#   ('to', 'O'),
#   ('hot', 'O'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('freezing', 'O'),
#   ('is', 'O'),
#   ('related', 'O'),
#   ('to', 'O'),
#   ('cold', 'O'),
#   ('.', 'O')],
#  [(')', 'O'),
#   ('We', 'O'),
#   ('will', 'O'),
#   ('call', 'O'),
#   ('this', 'O'),
#   ('the', 'O'),
#   ('contrast', 'O'),
#   ('hypothesis', 'O'),
#   ('.', 'O')],
#  [('We', 'O'),
#   ('begin', 'O'),
#   ('with', 'O'),
#   ('a', 'O'),
#   ('large', 'B'),
#   ('crowdsourcing', 'B'),
#   ('experiment', 'I'),
#   ('to', 'O'),
#   ('determine', 'O'),
#   ('the', 'O'),
#   ('amount', 'O'),
#   ('of', 'O'),
#   ('human', 'O'),
#   ('agreement', 'O'),
#   ('on', 'O'),
#   ('the', 'O'),
#   ('concept', 'O'),
#   ('of', 'O'),
#   ('oppositeness', 'O'),
#   ('and', 'O'),
#   ('its', 'O'),
#   ('different', 'O'),
#   ('kinds', 'O'),
#   ('.', 'O')],
#  [('In', 'O'),
#   ('the', 'O'),
#   ('process', 'O'),
#   (',', 'O'),
#   ('we', 'O'),
#   ('flesh', 'O'),
#   ('out', 'O'),
#   ('key', 'O'),
#   ('features', 'O'),
#   ('of', 'O'),
#   ('different', 'O'),
#   ('kinds', 'O'),
#   ('of', 'O'),
#   ('opposites', 'O'),
#   ('.', 'O')],
#  [('We', 'O'),
#   ('then', 'O'),
#   ('present', 'O'),
#   ('an', 'O'),
#   ('automatic', 'O'),
#   ('and', 'O'),
#   ('empirical', 'B'),
#   ('measure', 'I'),
#   ('of', 'O'),
#   ('lexical', 'B'),
#   ('contrast', 'I'),
#   ('that', 'O'),
#   ('relies', 'O'),
#   ('on', 'O'),
#   ('the', 'O'),
#   ('contrast', 'O'),
#   ('hypothesis', 'O'),
#   (',', 'O'),
#   ('corpus', 'B'),
#   ('statistics', 'O'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('the', 'O'),
#   ('structure', 'O'),
#   ('of', 'O'),
#   ('a', 'O'),
#   ('Roget', 'B'),
#   ('-', 'I'),
#   ('like', 'I'),
#   ('thesaurus', 'I'),
#   ('.', 'O')],
#  [('We', 'O'),
#   ('show', 'O'),
#   ('how', 'O'),
#   (',', 'O'),
#   ('using', 'O'),
#   ('four', 'O'),
#   ('different', 'O'),
#   ('data', 'B'),
#   ('sets', 'I'),
#   (',', 'O'),
#   ('we', 'O'),
#   ('evaluated', 'B'),
#   ('our', 'O'),
#   ('approach', 'O'),
#   ('on', 'O'),
#   ('two', 'O'),
#   ('different', 'O'),
#   ('tasks', 'B'),
#   (',', 'O'),
#   ('solving', 'O'),
#   ('“', 'O'),
#   ('most', 'O'),
#   ('contrasting', 'O'),
#   ('word', 'O'),
#   ('”', 'O'),
#   ('questions', 'O'),
#   ('and', 'O'),
#   ('distinguishing', 'O'),
#   ('synonyms', 'B'),
#   ('from', 'O'),
#   ('opposites', 'O'),
#   ('.', 'O')],
#  [('The', 'O'),
#   ('results', 'O'),
#   ('are', 'O'),
#   ('analyzed', 'O'),
#   ('across', 'O'),
#   ('four', 'O'),
#   ('parts', 'B'),
#   ('of', 'I'),
#   ('speech', 'I'),
#   ('and', 'O'),
#   ('across', 'O'),
#   ('five', 'O'),
#   ('different', 'O'),
#   ('kinds', 'O'),
#   ('of', 'O'),
#   ('opposites', 'O'),
#   ('.', 'O')],
#  [('We', 'O'),
#   ('show', 'O'),
#   ('that', 'O'),
#   ('the', 'O'),
#   ('proposed', 'O'),
#   ('measure', 'O'),
#   ('of', 'O'),
#   ('lexical', 'B'),
#   ('contrast', 'I'),
#   ('obtains', 'O'),
#   ('high', 'O'),
#   ('precision', 'O'),
#   ('and', 'O'),
#   ('large', 'O'),
#   ('coverage', 'O'),
#   (',', 'O'),
#   ('outperforming', 'O'),
#   ('existing', 'O'),
#   ('methods', 'O'),
#   ('.', 'O')],
#  [('This', 'O'),
#   ('work', 'O'),
#   ('is', 'O'),
#   ('focused', 'O'),
#   ('on', 'O'),
#   ('in', 'O'),
#   ('machine', 'B'),
#   ('learning', 'I'),
#   ('for', 'O'),
#   ('coreference', 'B'),
#   ('resolution', 'I'),
#   ('.', 'O')],
#  [('Coreference', 'B'),
#   ('resolution', 'I'),
#   ('is', 'O'),
#   ('a', 'O'),
#   ('natural', 'B'),
#   ('language', 'I'),
#   ('processing', 'I'),
#   ('task', 'I'),
#   ('that', 'O'),
#   ('consists', 'O'),
#   ('of', 'O'),
#   ('determining', 'O'),
#   ('the', 'O'),
#   ('expressions', 'O'),
#   ('in', 'O'),
#   ('a', 'O'),
#   ('discourse', 'B'),
#   ('that', 'O'),
#   ('refer', 'O'),
#   ('to', 'O'),
#   ('the', 'O'),
#   ('same', 'O'),
#   ('entity', 'O'),
#   ('.', 'O')],
#  [('The', 'O'),
#   ('main', 'O'),
#   ('contributions', 'O'),
#   ('of', 'O'),
#   ('this', 'O'),
#   ('article', 'O'),
#   ('are', 'O'),
#   ('(', 'O'),
#   ('i', 'O'),
#   (')', 'O'),
#   ('a', 'O'),
#   ('new', 'O'),
#   ('approach', 'O'),
#   ('to', 'O'),
#   ('coreference', 'B'),
#   ('resolution', 'I'),
#   ('based', 'O'),
#   ('on', 'O'),
#   ('constraint', 'B'),
#   ('satisfaction', 'I'),
#   (',', 'O'),
#   ('using', 'O'),
#   ('a', 'O'),
#   ('hypergraph', 'B'),
#   ('to', 'O'),
#   ('represent', 'O'),
#   ('the', 'O'),
#   ('problem', 'O'),
#   ('and', 'O'),
#   ('solving', 'O'),
#   ('it', 'O'),
#   ('by', 'O'),
#   ('relaxation', 'B'),
#   ('labeling', 'I'),
#   (';', 'O'),
#   ('and', 'O'),
#   ('(', 'O'),
#   ('ii', 'O'),
#   (')', 'O'),
#   ('research', 'O'),
#   ('towards', 'O'),
#   ('improving', 'O'),
#   ('coreference', 'B'),
#   ('resolution', 'I'),
#   ('performance', 'I'),
#   ('using', 'O'),
#   ('world', 'B'),
#   ('knowledge', 'I'),
#   ('extracted', 'O'),
#   ('from', 'O'),
#   ('Wikipedia', 'O'),
#   ('.', 'O')],
#  [('The', 'O'),
#   ('developed', 'O'),
#   ('approach', 'O'),
#   ('is', 'O'),
#   ('able', 'O'),
#   ('to', 'O'),
#   ('use', 'O'),
#   ('an', 'O'),
#   ('entity', 'B'),
#   ('-', 'I'),
#   ('mention', 'I'),
#   ('classification', 'I'),
#   ('model', 'I'),
#   ('with', 'O'),
#   ('more', 'O'),
#   ('expressiveness', 'O'),
#   ('than', 'O'),
#   ('the', 'O'),
#   ('pair', 'B'),
#   ('-', 'I'),
#   ('based', 'I'),
#   ('ones', 'O'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('overcome', 'O'),
#   ('the', 'O'),
#   ('weaknesses', 'O'),
#   ('of', 'O'),
#   ('previous', 'O'),
#   ('approaches', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('state', 'B'),
#   ('of', 'I'),
#   ('the', 'I'),
#   ('art', 'I'),
#   ('such', 'O'),
#   ('as', 'O'),
#   ('linking', 'B'),
#   ('contradictions', 'I'),
#   (',', 'O'),
#   ('classifications', 'B'),
#   ('without', 'O'),
#   ('context', 'B'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('lack', 'O'),
#   ('of', 'O'),
#   ('information', 'O'),
#   ('evaluating', 'O'),
#   ('pairs', 'O'),
#   ('.', 'O')],
#  [('Furthermore', 'O'),
#   (',', 'O'),
#   ('the', 'O'),
#   ('approach', 'O'),
#   ('allows', 'O'),
#   ('the', 'O'),
#   ('incorporation', 'O'),
#   ('of', 'O'),
#   ('new', 'O'),
#   ('information', 'O'),
#   ('by', 'O'),
#   ('adding', 'O'),
#   ('constraints', 'O'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('research', 'O'),
#   ('has', 'O'),
#   ('been', 'O'),
#   ('done', 'O'),
#   ('in', 'O'),
#   ('order', 'O'),
#   ('to', 'O'),
#   ('use', 'O'),
#   ('world', 'O'),
#   ('knowledge', 'O'),
#   ('to', 'O'),
#   ('improve', 'O'),
#   ('performances', 'O'),
#   ('.', 'O')],
#  [('RelaxCor', 'O'),
#   (',', 'O'),
#   ('the', 'O'),
#   ('implementation', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('approach', 'O'),
#   (',', 'O'),
#   ('achieved', 'O'),
#   ('results', 'O'),
#   ('at', 'O'),
#   ('the', 'O'),
#   ('state', 'B'),
#   ('-', 'I'),
#   ('of', 'I'),
#   ('-', 'I'),
#   ('the', 'I'),
#   ('-', 'I'),
#   ('art', 'I'),
#   ('level', 'O'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('participated', 'O'),
#   ('in', 'O'),
#   ('international', 'O'),
#   ('competitions', 'O'),
#   (':', 'O'),
#   ('SemEval-2010', 'O'),
#   ('and', 'O'),
#   ('CoNLL-2011', 'O'),
#   ('.', 'O')],
#  [('RelaxCor', 'O'),
#   ('achieved', 'O'),
#   ('second', 'O'),
#   ('place', 'O'),
#   ('in', 'O'),
#   ('CoNLL-2011', 'O'),
#   ('.', 'O')],
#  [('We', 'O'),
#   ('present', 'O'),
#   ('a', 'O'),
#   ('constituency', 'B'),
#   ('parsing', 'I'),
#   ('system', 'O'),
#   ('for', 'O'),
#   ('Modern', 'O'),
#   ('Hebrew', 'O'),
#   ('.', 'O')],
#  [('The', 'O'),
#   ('system', 'O'),
#   ('is', 'O'),
#   ('based', 'O'),
#   ('on', 'O'),
#   ('the', 'O'),
#   ('PCFG', 'B'),
#   ('-', 'I'),
#   ('LA', 'I'),
#   ('parsing', 'B'),
#   ('method', 'O'),
#   ('of', 'O'),
#   ('Petrov', 'O'),
#   ('et', 'O'),
#   ('al', 'O'),
#   ('.', 'O')],
#  [('2006', 'O'),
#   (',', 'O'),
#   ('which', 'O'),
#   ('is', 'O'),
#   ('extended', 'O'),
#   ('in', 'O'),
#   ('various', 'O'),
#   ('ways', 'O'),
#   ('in', 'O'),
#   ('order', 'O'),
#   ('to', 'O'),
#   ('accommodate', 'O'),
#   ('the', 'O'),
#   ('specificities', 'O'),
#   ('of', 'O'),
#   ('Hebrew', 'O'),
#   ('as', 'O'),
#   ('a', 'O'),
#   ('morphologically', 'B'),
#   ('rich', 'I'),
#   ('language', 'I'),
#   ('with', 'O'),
#   ('a', 'O'),
#   ('small', 'O'),
#   ('treebank', 'B'),
#   ('.', 'O')],
#  [('We', 'O'),
#   ('show', 'O'),
#   ('that', 'O'),
#   ('parsing', 'B'),
#   ('performance', 'O'),
#   ('can', 'O'),
#   ('be', 'O'),
#   ('enhanced', 'O'),
#   ('by', 'O'),
#   ('utilizing', 'O'),
#   ('a', 'O'),
#   ('language', 'O'),
#   ('resource', 'O'),
#   ('external', 'O'),
#   ('to', 'O'),
#   ('the', 'O'),
#   ('treebank', 'B'),
#   (',', 'O'),
#   ('specifically', 'O'),
#   (',', 'O'),
#   ('a', 'O'),
#   ('lexicon', 'B'),
#   ('-', 'I'),
#   ('based', 'I'),
#   ('morphological', 'B'),
#   ('analyzer', 'I'),
#   ('.', 'O')],
#  [('We', 'O'),
#   ('present', 'O'),
#   ('a', 'O'),
#   ('computational', 'B'),
#   ('model', 'I'),
#   ('of', 'O'),
#   ('interfacing', 'O'),
#   ('the', 'O'),
#   ('external', 'O'),
#   ('lexicon', 'B'),
#   ('and', 'O'),
#   ('a', 'O'),
#   ('treebank', 'B'),
#   ('-', 'I'),
#   ('based', 'I'),
#   ('parser', 'I'),
#   (',', 'O'),
#   ('also', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('common', 'O'),
#   ('case', 'O'),
#   ('where', 'O'),
#   ('the', 'O'),
#   ('lexicon', 'B'),
#   ('and', 'O'),
#   ('the', 'O'),
#   ('treebank', 'B'),
#   ('follow', 'O'),
#   ('different', 'O'),
#   ('annotation', 'B'),
#   ('schemes', 'I'),
#   ('.', 'O')],
#  [('We', 'O'),
#   ('show', 'O'),
#   ('that', 'O'),
#   ('Hebrew', 'O'),
#   ('word', 'B'),
#   ('-', 'I'),
#   ('segmentation', 'I'),
#   ('and', 'O'),
#   ('constituency', 'B'),
#   ('-', 'I'),
#   ('parsing', 'I'),
#   ('can', 'O'),
#   ('be', 'O'),
#   ('performed', 'O'),
#   ('jointly', 'O'),
#   ('using', 'O'),
#   ('CKY', 'B'),
#   ('lattice', 'I'),
#   ('parsing', 'I'),
#   ('.', 'O')],
#  [('Performing', 'O'),
#   ('the', 'O'),
#   ('tasks', 'O'),
#   ('jointly', 'O'),
#   ('is', 'O'),
#   ('effective', 'O'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('substantially', 'O'),
#   ('outperforms', 'O'),
#   ('a', 'O'),
#   ('pipeline', 'B'),
#   ('-', 'I'),
#   ('based', 'I'),
#   ('model', 'I'),
#   ('.', 'O')],
#  [('We', 'O'),
#   ('suggest', 'O'),
#   ('modeling', 'O'),
#   ('grammatical', 'B'),
#   ('agreement', 'I'),
#   ('in', 'O'),
#   ('a', 'O'),
#   ('constituency', 'B'),
#   ('-', 'I'),
#   ('based', 'I'),
#   ('parser', 'I'),
#   ('as', 'O'),
#   ('a', 'O'),
#   ('filter', 'O'),
#   ('mechanism', 'O'),
#   ('that', 'O'),
#   ('is', 'O'),
#   ('orthogonal', 'O'),
#   ('to', 'O'),
#   ('the', 'O'),
#   ('grammar', 'O'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('present', 'O'),
#   ('a', 'O'),
#   ('concrete', 'O'),
#   ('implementation', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('method', 'O'),
#   ('.', 'O')],
#  [('Although', 'O'),
#   ('the', 'O'),
#   ('constituency', 'B'),
#   ('parser', 'I'),
#   ('does', 'O'),
#   ('not', 'O'),
#   ('make', 'O'),
#   ('many', 'O'),
#   ('agreement', 'O'),
#   ('mistakes', 'O'),
#   ('to', 'O'),
#   ('begin', 'O'),
#   ('with', 'O'),
#   (',', 'O'),
#   ('the', 'O'),
#   ('filter', 'O'),
#   ('mechanism', 'O'),
#   ('is', 'O'),
#   ('effective', 'O'),
#   ('in', 'O'),
#   ('fixing', 'O'),
#   ('the', 'O'),
#   ('agreement', 'O'),
#   ('mistakes', 'O'),
#   ('that', 'O'),
#   ('the', 'O'),
#   ('parser', 'B'),
#   ('does', 'O'),
#   ('make', 'O'),
#   ('.', 'O')],
#  [('These', 'O'),
#   ('contributions', 'O'),
#   ('extend', 'O'),
#   ('outside', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('scope', 'O'),
#   ('of', 'O'),
#   ('Hebrew', 'O'),
#   ('processing', 'B'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('are', 'O'),
#   ('of', 'O'),
#   ('general', 'O'),
#   ('applicability', 'O'),
#   ('to', 'O'),
#   ('the', 'O'),
#   ('NLP', 'B'),
#   ('community', 'O'),
#   ('.', 'O')],
#  [('Hebrew', 'O'),
#   ('is', 'O'),
#   ('a', 'O'),
#   ('specific', 'O'),
#   ('case', 'O'),
#   ('of', 'O'),
#   ('a', 'O'),
#   ('morphologically', 'B'),
#   ('rich', 'I'),
#   ('language', 'I'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('ideas', 'O'),
#   ('presented', 'O'),
#   ('in', 'O'),
#   ('this', 'O'),
#   ('work', 'O'),
#   ('are', 'O'),
#   ('useful', 'O'),
#   ('also', 'O'),
#   ('for', 'O'),
#   ('processing', 'B'),
#   ('other', 'O'),
#   ('languages', 'O'),
#   (',', 'O'),
#   ('including', 'O'),
#   ('English', 'O'),
#   ('.', 'O')],
#  [('The', 'O'),
#   ('lattice', 'B'),
#   ('-', 'I'),
#   ('based', 'I'),
#   ('parsing', 'I'),
#   ('methodology', 'O'),
#   ('is', 'O'),
#   ('useful', 'O'),
#   ('in', 'O'),
#   ('any', 'O'),
#   ('case', 'O'),
#   ('where', 'O'),
#   ('the', 'O'),
#   ('input', 'O'),
#   ('is', 'O'),
#   ('uncertain', 'O'),
#   ('.', 'O')],
#  [('Extending', 'O'),
#   ('the', 'O'),
#   ('lexical', 'B'),
#   ('coverage', 'I'),
#   ('of', 'O'),
#   ('a', 'O'),
#   ('treebank', 'B'),
#   ('-', 'I'),
#   ('derived', 'I'),
#   ('parser', 'I'),
#   ('using', 'O'),
#   ('an', 'O'),
#   ('external', 'O'),
#   ('lexicon', 'B'),
#   ('is', 'O'),
#   ('relevant', 'O'),
#   ('for', 'O'),
#   ('any', 'O'),
#   ('language', 'O'),
#   ('with', 'O'),
#   ('a', 'O'),
#   ('small', 'O'),
#   ('treebank', 'B'),
#   ('.', 'O')],
#  [('Multiword', 'B'),
#   ('expressions', 'I'),
#   ('lie', 'O'),
#   ('at', 'O'),
#   ('the', 'O'),
#   ('syntax', 'B'),
#   ('/', 'O'),
#   ('semantics', 'B'),
#   ('interface', 'O'),
#   ('and', 'O'),
#   ('have', 'O'),
#   ('motivated', 'O'),
#   ('alternative', 'O'),
#   ('theories', 'O'),
#   ('of', 'O'),
#   ('syntax', 'B'),
#   ('like', 'O'),
#   ('Construction', 'B'),
#   ('Grammar', 'I'),
#   ('.', 'O')],
#  [('Until', 'O'),
#   ('now', 'O'),
#   (',', 'O'),
#   ('however', 'O'),
#   (',', 'O'),
#   ('syntactic', 'B'),
#   ('analysis', 'I'),
#   ('and', 'O'),
#   ('multiword', 'B'),
#   ('expression', 'I'),
#   ('identification', 'I'),
#   ('have', 'O'),
#   ('been', 'O'),
#   ('modeled', 'O'),
#   ('separately', 'O'),
#   ('in', 'O'),
#   ('natural', 'B'),
#   ('language', 'I'),
#   ('processing', 'I'),
#   ('.', 'O')],
#  [('We', 'O'),
#   ('develop', 'O'),
#   ('two', 'O'),
#   ('structured', 'B'),
#   ('prediction', 'I'),
#   ('models', 'I'),
#   ('for', 'O'),
#   ('joint', 'B'),
#   ('parsing', 'I'),
#   ('and', 'O'),
#   ('multiword', 'B'),
#   ('expression', 'I'),
#   ('identification', 'I'),
#   ('.', 'O')],
#  [('The', 'O'),
#   ('first', 'O'),
#   ('is', 'O'),
#   ('based', 'O'),
#   ('on', 'O'),
#   ('context', 'B'),
#   ('-', 'I'),
#   ('free', 'I'),
#   ('grammars', 'I'),
#   ('and', 'O'),
#   ('the', 'O'),
#   ('second', 'O'),
#   ('uses', 'O'),
#   ('tree', 'B'),
#   ('substitution', 'I'),
#   ('grammars', 'I'),
#   (',', 'O'),
#   ('a', 'O'),
#   ('formalism', 'B'),
#   ('that', 'O'),
#   ('can', 'O'),
#   ('store', 'O'),
#   ('larger', 'O'),
#   ('syntactic', 'B'),
#   ('fragments', 'I'),
#   ('.', 'O')],
#  [('Our', 'O'),
#   ('experiments', 'O'),
#   ('show', 'O'),
#   ('that', 'O'),
#   ('both', 'O'),
#   ('models', 'B'),
#   ('can', 'O'),
#   ('identify', 'O'),
#   ('multiword', 'B'),
#   ('expressions', 'I'),
#   ('with', 'O'),
#   ('much', 'O'),
#   ('higher', 'O'),
#   ('accuracy', 'B'),
#   ('than', 'O'),
#   ('a', 'O'),
#   ('state', 'B'),
#   ('-', 'I'),
#   ('of', 'I'),
#   ('-', 'I'),
#   ('the', 'I'),
#   ('-', 'I'),
#   ('art', 'I'),
#   ('system', 'O'),
#   ('based', 'O'),
#   ('on', 'O'),
#   ('word', 'B'),
#   ('co', 'I'),
#   ('-', 'I'),
#   ('occurrence', 'I'),
#   ('statistics', 'O'),
#   ('.', 'O')],
#  [('We', 'O'),
#   ('experiment', 'O'),
#   ('with', 'O'),
#   ('Arabic', 'O'),
#   ('and', 'O'),
#   ('French', 'O'),
#   (',', 'O'),
#   ('which', 'O'),
#   ('both', 'O'),
#   ('have', 'O'),
#   ('pervasive', 'B'),
#   ('multiword', 'I'),
#   ('expressions', 'I'),
#   ('.', 'O')],
#  [('Relative', 'O'),
#   ('to', 'O'),
#   ('English', 'O'),
#   (',', 'O'),
#   ('they', 'O'),
#   ('also', 'O'),
#   ('have', 'O'),
#   ('richer', 'O'),
#   ('morphology', 'B'),
#   (',', 'O'),
#   ('which', 'O'),
#   ('induces', 'O'),
#   ('lexical', 'B'),
#   ('sparsity', 'I'),
#   ('in', 'O'),
#   ('finite', 'O'),
#   ('corpora', 'B'),
#   ('.', 'O')],
#  [('To', 'O'),
#   ('combat', 'O'),
#   ('this', 'O'),
#   ('sparsity', 'B'),
#   (',', 'O'),
#   ('we', 'O'),
#   ('develop', 'O'),
#   ('a', 'O'),
#   ('simple', 'O'),
#   ('factored', 'B'),
#   ('lexical', 'I'),
#   ('representation', 'I'),
#   ('for', 'O'),
#   ('the', 'O'),
#   ('context', 'B'),
#   ('-', 'I'),
#   ('free', 'I'),
#   ('parsing', 'I'),
#   ('model', 'I'),
#   ('.', 'O')],
#  [('Morphological', 'B'),
#   ('analyses', 'O'),
#   ('are', 'O'),
#   ('automatically', 'O'),
#   ('transformed', 'O'),
#   ('into', 'O'),
#   ('rich', 'O'),
#   ('feature', 'B'),
#   ('tags', 'I'),
#   ('that', 'O'),
#   ('are', 'O'),
#   ('scored', 'O'),
#   ('jointly', 'O'),
#   ('with', 'O'),
#   ('lexical', 'B'),
#   ('items', 'I'),
#   ('.', 'O')],
#  [('This', 'O'),
#   ('technique', 'O'),
#   (',', 'O'),
#   ('which', 'O'),
#   ('we', 'O'),
#   ('call', 'O'),
#   ('a', 'O'),
#   ('factored', 'B'),
#   ('lexicon', 'I'),
#   (',', 'O'),
#   ('improves', 'O'),
#   ('both', 'O'),
#   ('standard', 'O'),
#   ('parsing', 'B'),
#   ('and', 'O'),
#   ('multiword', 'B'),
#   ('expression', 'I'),
#   ('identification', 'I'),
#   ('accuracy', 'B'),
#   ('.', 'O')],
#  [('Most', 'O'),
#   ('morphologically', 'B'),
#   ('rich', 'I'),
#   ('languages', 'I'),
#   ('with', 'O'),
#   ('free', 'B'),
#   ('word', 'I'),
#   ('order', 'I'),
#   ('use', 'O'),
#   ('case', 'B'),
#   ('systems', 'I'),
#   ('to', 'O'),
#   ('mark', 'O'),
#   ('the', 'O'),
#   ('grammatical', 'B'),
#   ('function', 'I'),
#   ('of', 'O'),
#   ('nominal', 'B'),
#   ('elements', 'I'),
#   (',', 'O'),
#   ('especially', 'O'),
#   ('for', 'O'),
#   ('the', 'O'),
#   ('core', 'B'),
#   ('argument', 'I'),
#   ('functions', 'I'),
#   ('of', 'O'),
#   ('a', 'O'),
#   ('verb', 'O'),
#   ('.', 'O')],
#  [('The', 'O'),
#   ('standard', 'O'),
#   ('pipeline', 'B'),
#   ('approach', 'I'),
#   ('in', 'O'),
#   ('syntactic', 'B'),
#   ('dependency', 'I'),
#   ('parsing', 'I'),
#   ('assumes', 'O'),
#   ('a', 'O'),
#   ('complete', 'O'),
#   ('disambiguation', 'B'),
#   ('of', 'O'),
#   ('morphological', 'B'),
#   ('(', 'O'),
#   ('case', 'B'),
#   (')', 'O'),
#   ('information', 'O'),
#   ('prior', 'O'),
#   ('to', 'O'),
#   ('automatic', 'B'),
#   ('syntactic', 'I'),
#   ('analysis', 'I'),
#   ('.', 'O')],
#  [('Parsing', 'B'),
#   ('experiments', 'I'),
#   ('on', 'O'),
#   ('Czech', 'O'),
#   (',', 'O'),
#   ('German', 'O'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('Hungarian', 'O'),
#   ('show', 'O'),
#   ('that', 'O'),
#   ('this', 'O'),
#   ('approach', 'O'),
#   ('is', 'O'),
#   ('susceptible', 'O'),
#   ('to', 'O'),
#   ('propagating', 'O'),
#   ('morphological', 'B'),
#   ('annotation', 'I'),
#   ('errors', 'O'),
#   ('when', 'O'),
#   ('parsing', 'B'),
#   ('languages', 'O'),
#   ('displaying', 'O'),
#   ('syncretism', 'O'),
#   ('in', 'O'),
#   ('their', 'O'),
#   ('morphological', 'B'),
#   ('case', 'I'),
#   ('paradigms', 'O'),
#   ('.', 'O')],
#  [('We', 'O'),
#   ('develop', 'O'),
#   ('a', 'O'),
#   ('different', 'O'),
#   ('architecture', 'O'),
#   ('where', 'O'),
#   ('we', 'O'),
#   ('use', 'O'),
#   ('case', 'B'),
#   ('as', 'O'),
#   ('a', 'O'),
#   ('possibly', 'O'),
#   ('underspecified', 'O'),
#   ('filtering', 'O'),
#   ('device', 'O'),
#   ('restricting', 'O'),
#   ('the', 'O'),
#   ('options', 'O'),
#   ('for', 'O'),
#   ('syntactic', 'B'),
#   ('analysis', 'I'),
#   ('.', 'O')],
#  [('Carefully', 'O'),
#   ('designed', 'O'),
#   ('morpho', 'B'),
#   ('-', 'I'),
#   ('syntactic', 'I'),
#   ('constraints', 'I'),
#   ('can', 'O'),
#   ('delimit', 'O'),
#   ('the', 'O'),
#   ('search', 'O'),
#   ('space', 'O'),
#   ('of', 'O'),
#   ('a', 'O'),
#   ('statistical', 'B'),
#   ('dependency', 'I'),
#   ('parser', 'I'),
#   ('and', 'O'),
#   ('exclude', 'O'),
#   ('solutions', 'O'),
#   ('that', 'O'),
#   ('would', 'O'),
#   ('violate', 'O'),
#   ('the', 'O'),
#   ('restrictions', 'O'),
#   ('overtly', 'O'),
#   ('marked', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('morphology', 'B'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('words', 'O'),
#   ('in', 'O'),
#   ('a', 'O'),
#   ('given', 'O'),
#   ('sentence', 'O'),
#   ('.', 'O')],
#  [('The', 'O'),
#   ('constrained', 'O'),
#   ('system', 'O'),
#   ('outperforms', 'O'),
#   ('a', 'O'),
#   ('state', 'B'),
#   ('-', 'I'),
#   ('of', 'I'),
#   ('-', 'I'),
#   ('the', 'I'),
#   ('-', 'I'),
#   ('art', 'I'),
#   ('data', 'B'),
#   ('-', 'I'),
#   ('driven', 'I'),
#   ('pipeline', 'B'),
#   ('architecture', 'I'),
#   (',', 'O'),
#   ('as', 'O'),
#   ('we', 'O'),
#   ('show', 'O'),
#   ('experimentally', 'O'),
#   (',', 'O'),
#   ('and', 'O'),
#   (',', 'O'),
#   ('in', 'O'),
#   ('addition', 'O'),
#   (',', 'O'),
#   ('the', 'O'),
#   ('parser', 'B'),
#   ('output', 'I'),
#   ('comes', 'O'),
#   ('with', 'O'),
#   ('guarantees', 'O'),
#   ('about', 'O'),
#   ('local', 'O'),
#   ('and', 'O'),
#   ('global', 'B'),
#   ('morpho', 'I'),
#   ('-', 'I'),
#   ('syntactic', 'I'),
#   ('wellformedness', 'I'),
#   (',', 'O'),
#   ('which', 'O'),
#   ('can', 'O'),
#   ('be', 'O'),
#   ('useful', 'O'),
#   ('for', 'O'),
#   ('downstream', 'O'),
#   ('applications', 'O'),
#   ('.', 'O')],
#  [('Word', 'B'),
#   ('sense', 'I'),
#   ('disambiguation', 'I'),
#   ('(', 'O'),
#   ('WSD', 'B'),
#   (')', 'O'),
#   ('is', 'O'),
#   ('an', 'O'),
#   ('old', 'O'),
#   ('and', 'O'),
#   ('important', 'O'),
#   ('task', 'O'),
#   ('in', 'O'),
#   ('computational', 'B'),
#   ('linguistics', 'I'),
#   ('that', 'O'),
#   ('still', 'O'),
#   ('remains', 'O'),
#   ('challenging', 'O'),
#   (',', 'O'),
#   ('to', 'O'),
#   ('machines', 'O'),
#   ('as', 'O'),
#   ('well', 'O'),
#   ('as', 'O'),
#   ('to', 'O'),
#   ('human', 'O'),
#   ('annotators', 'B'),
#   ('.', 'O')],
#  [('Recently', 'O'),
#   ('there', 'O'),
#   ('have', 'O'),
#   ('been', 'O'),
#   ('several', 'O'),
#   ('proposals', 'O'),
#   ('for', 'O'),
#   ('representing', 'O'),
#   ('word', 'O'),
#   ('meaning', 'O'),
#   ('in', 'O'),
#   ('context', 'B'),
#   ('that', 'O'),
#   ('diverge', 'O'),
#   ('from', 'O'),
#   ('the', 'O'),
#   ('traditional', 'O'),
#   ('use', 'O'),
#   ('of', 'O'),
#   ('a', 'O'),
#   ('single', 'O'),
#   ('best', 'O'),
#   ('sense', 'O'),
#   ('for', 'O'),
#   ('each', 'O'),
#   ('occurrence', 'O'),
#   ('.', 'O')],
#  [('They', 'O'),
#   ('represent', 'O'),
#   ('word', 'O'),
#   ('meaning', 'O'),
#   ('in', 'O'),
#   ('context', 'B'),
#   ('through', 'O'),
#   ('multiple', 'O'),
#   ('paraphrases', 'O'),
#   (',', 'O'),
#   ('as', 'O'),
#   ('points', 'O'),
#   ('in', 'O'),
#   ('vector', 'B'),
#   ('space', 'I'),
#   (',', 'O'),
#   ('or', 'O'),
#   ('as', 'O'),
#   ('distributions', 'B'),
#   ('over', 'O'),
#   ('latent', 'O'),
#   ('senses', 'O'),
#   ('.', 'O')],
#  [('New', 'O'),
#   ('methods', 'O'),
#   ('of', 'O'),
#   ('evaluating', 'O'),
#   ('and', 'O'),
#   ('comparing', 'O'),
#   ('these', 'O'),
#   ('different', 'O'),
#   ('representations', 'O'),
#   ('are', 'O'),
#   ('needed', 'O'),
#   ('.', 'O')],
#  [('In', 'O'),
#   ('this', 'O'),
#   ('paper', 'O'),
#   ('we', 'O'),
#   ('propose', 'O'),
#   ('two', 'O'),
#   ('novel', 'O'),
#   ('annotation', 'B'),
#   ('schemes', 'I'),
#   ('that', 'O'),
#   ('characterize', 'O'),
#   ('word', 'O'),
#   ('meaning', 'O'),
#   ('in', 'O'),
#   ('context', 'B'),
#   ('in', 'O'),
#   ('a', 'O'),
#   ('graded', 'O'),
#   ('fashion', 'O'),
#   ('.', 'O')],
#  [('In', 'O'),
#   ('WSsim', 'B'),
#   ('annotation', 'I'),
#   (',', 'O'),
#   ('the', 'O'),
#   ('applicability', 'O'),
#   ('of', 'O'),
#   ('each', 'O'),
#   ('dictionary', 'O'),
#   ('sense', 'O'),
#   ('is', 'O'),
#   ('rated', 'O'),
#   ('on', 'O'),
#   ('an', 'O'),
#   ('ordinal', 'B'),
#   ('scale', 'I'),
#   ('.', 'O')],
#  [('Usim', 'B'),
#   ('annotation', 'I'),
#   ('directly', 'O'),
#   ('rates', 'O'),
#   ('the', 'O'),
#   ('similarity', 'O'),
#   ('of', 'O'),
#   ('pairs', 'O'),
#   ('of', 'O'),
#   ('usages', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('same', 'O'),
#   ('lemma', 'B'),
#   (',', 'O'),
#   ('again', 'O'),
#   ('on', 'O'),
#   ('a', 'O'),
#   ('scale', 'O'),
#   ('.', 'O')],
#  [('We', 'O'),
#   ('find', 'O'),
#   ('that', 'O'),
#   ('the', 'O'),
#   ('novel', 'O'),
#   ('annotation', 'O'),
#   ('schemes', 'O'),
#   ('show', 'O'),
#   ('good', 'O'),
#   ('interannotator', 'B'),
#   ('agreement', 'I'),
#   (',', 'O'),
#   ('as', 'O'),
#   ('well', 'O'),
#   ('as', 'O'),
#   ('a', 'O'),
#   ('strong', 'B'),
#   ('correlation', 'I'),
#   ('with', 'O'),
#   ('traditional', 'O'),
#   ('single', 'O'),
#   ('-', 'O'),
#   ('sense', 'O'),
#   ('annotation', 'B'),
#   ('and', 'O'),
#   ('with', 'O'),
#   ('annotation', 'B'),
#   ('of', 'O'),
#   ('multiple', 'O'),
#   ('lexical', 'B'),
#   ('paraphrases', 'I'),
#   ('.', 'O')],
#  [('Annotators', 'B'),
#   ('make', 'O'),
#   ('use', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('whole', 'O'),
#   ('ordinal', 'B'),
#   ('scale', 'I'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('give', 'O'),
#   ('fine', 'B'),
#   ('-', 'I'),
#   ('grained', 'I'),
#   ('judgments', 'I'),
#   ('that', 'O'),
#   ('“', 'O'),
#   ('mix', 'O'),
#   ('and', 'O'),
#   ('match', 'O'),
#   ('”', 'O'),
#   ('senses', 'O'),
#   ('for', 'O'),
#   ('each', 'O'),
#   ('individual', 'O'),
#   ('usage', 'O'),
#   ('.', 'O')],
#  [('We', 'O'),
#   ('also', 'O'),
#   ('find', 'O'),
#   ('that', 'O'),
#   ('the', 'O'),
#   ('Usim', 'B'),
#   ('ratings', 'I'),
#   ('obey', 'O'),
#   ('the', 'O'),
#   ('triangle', 'O'),
#   ('inequality', 'O'),
#   (',', 'O'),
#   ('justifying', 'O'),
#   ('models', 'O'),
#   ('that', 'O'),
#   ('treat', 'O'),
#   ('usage', 'O'),
#   ('similarity', 'O'),
#   ('as', 'O'),
#   ('metric', 'B'),
#   ('.', 'O')],
#  [('There', 'O'),
#   ('has', 'O'),
#   ('recently', 'O'),
#   ('been', 'O'),
#   ('much', 'O'),
#   ('work', 'O'),
#   ('on', 'O'),
#   ('grouping', 'O'),
#   ('senses', 'O'),
#   ('into', 'O'),
#   ('coarse', 'B'),
#   ('-', 'I'),
#   ('grained', 'I'),
#   ('groups', 'I'),
#   ('.', 'O')],
#  [('We', 'O'),
#   ('demonstrate', 'O'),
#   ('that', 'O'),
#   ('graded', 'B'),
#   ('WSsim', 'I'),
#   ('and', 'O'),
#   ('Usim', 'B'),
#   ('ratings', 'I'),
#   ('can', 'O'),
#   ('be', 'O'),
#   ('used', 'O'),
#   ('to', 'O'),
#   ('analyze', 'O'),
#   ('existing', 'O'),
#   ('coarse', 'B'),
#   ('-', 'I'),
#   ('grained', 'I'),
#   ('sense', 'I'),
#   ('groupings', 'O'),
#   ('to', 'O'),
#   ('identify', 'O'),
#   ('sense', 'O'),
#   ('groups', 'O'),
#   ('that', 'O'),
#   ('may', 'O'),
#   ('not', 'O'),
#   ('match', 'O'),
#   ('intuitions', 'O'),
#   ('of', 'O'),
#   ('untrained', 'O'),
#   ('native', 'O'),
#   ('speakers', 'O'),
#   ('.', 'O')],
#  [('In', 'O'),
#   ('the', 'O'),
#   ('course', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('comparison', 'O'),
#   (',', 'O'),
#   ('we', 'O'),
#   ('also', 'O'),
#   ('show', 'O'),
#   ('that', 'O'),
#   ('the', 'O'),
#   ('WSsim', 'B'),
#   ('ratings', 'I'),
#   ('are', 'O'),
#   ('not', 'O'),
#   ('subsumed', 'O'),
#   ('by', 'O'),
#   ('any', 'O'),
#   ('static', 'B'),
#   ('sense', 'I'),
#   ('grouping', 'I'),
#   ('.', 'O')],
#  [('Recent', 'O'),
#   ('research', 'O'),
#   ('has', 'O'),
#   ('shown', 'O'),
#   ('clear', 'O'),
#   ('improvement', 'O'),
#   ('in', 'O'),
#   ('translation', 'B'),
#   ('quality', 'I'),
#   ('by', 'O'),
#   ('exploiting', 'O'),
#   ('linguistic', 'B'),
#   ('syntax', 'I'),
#   ('for', 'O'),
#   ('either', 'O'),
#   ('the', 'O'),
#   ('source', 'O'),
#   ('or', 'O'),
#   ('target', 'B'),
#   ('language', 'I'),
#   ('.', 'O')],
#  [('However', 'O'),
#   (',', 'O'),
#   ('when', 'O'),
#   ('using', 'O'),
#   ('syntax', 'B'),
#   ('for', 'O'),
#   ('both', 'O'),
#   ('languages', 'B'),
#   ('(', 'O'),
#   ('“', 'O'),
#   ('tree', 'B'),
#   ('-', 'I'),
#   ('to', 'I'),
#   ('-', 'I'),
#   ('tree', 'I'),
#   ('”', 'O'),
#   ('translation', 'B'),
#   (')', 'O'),
#   (',', 'O'),
#   ('there', 'O'),
#   ('is', 'O'),
#   ('evidence', 'O'),
#   ('that', 'O'),
#   ('syntactic', 'B'),
#   ('divergence', 'I'),
#   ('can', 'O'),
#   ('hamper', 'O'),
#   ('the', 'O'),
#   ('extraction', 'B'),
#   ('of', 'O'),
#   ('useful', 'O'),
#   ('rules', 'O'),
#   ('(', 'O'),
#   ('Ding', 'O'),
#   ('and', 'O'),
#   ('Palmer', 'O'),
#   ('2005', 'O'),
#   (')', 'O'),
#   ('.', 'O')],
#  [('Smith', 'O'),
#   ('and', 'O'),
#   ('Eisner', 'O'),
#   ('(', 'O'),
#   ('2006', 'O'),
#   (')', 'O'),
#   ('introduced', 'O'),
#   ('quasi', 'B'),
#   ('-', 'O'),
#   ('synchronous', 'B'),
#   ('grammar', 'I'),
#   (',', 'O'),
#   ('a', 'O'),
#   ('formalism', 'B'),
#   ('that', 'O'),
#   ('treats', 'O'),
#   ('non', 'O'),
#   ('-', 'O'),
#   ('isomorphic', 'B'),
#   ('structure', 'I'),
#   ('softly', 'O'),
#   ('using', 'O'),
#   ('features', 'B'),
#   ('rather', 'O'),
#   ('than', 'O'),
#   ('hard', 'O'),
#   ('constraints', 'O'),
#   ('.', 'O')],
#  [('Although', 'O'),
#   ('a', 'O'),
#   ('natural', 'B'),
#   ('fit', 'I'),
#   ('for', 'O'),
#   ('translation', 'B'),
#   ('modeling', 'I'),
#   (',', 'O'),
#   ('its', 'O'),
#   ('flexibility', 'O'),
#   ('has', 'O'),
#   ('proved', 'O'),
#   ('challenging', 'O'),
#   ('for', 'O'),
#   ('building', 'O'),
#   ('real', 'O'),
#   ('-', 'O'),
#   ('world', 'O'),
#   ('systems', 'O'),
#   ('.', 'O')],
#  [('In', 'O'),
#   ('this', 'O'),
#   ('article', 'O'),
#   (',', 'O'),
#   ('we', 'O'),
#   ('present', 'O'),
#   ('a', 'O'),
#   ('tree', 'O'),
#   ('-', 'O'),
#   ('to', 'O'),
#   ('-', 'O'),
#   ('tree', 'O'),
#   ('machine', 'B'),
#   ('translation', 'I'),
#   ('system', 'O'),
#   ('inspired', 'O'),
#   ('by', 'O'),
#   ('quasi', 'B'),
#   ('-', 'I'),
#   ('synchronous', 'I'),
#   ('grammar', 'I'),
#   ('.', 'O')],
#  [('The', 'O'),
#   ('core', 'O'),
#   ('of', 'O'),
#   ('our', 'O'),
#   ('approach', 'O'),
#   ('is', 'O'),
#   ('a', 'O'),
#   ('new', 'O'),
#   ('model', 'O'),
#   ('that', 'O'),
#   ('combines', 'O'),
#   ('phrases', 'B'),
#   ('and', 'O'),
#   ('dependency', 'B'),
#   ('syntax', 'I'),
#   (',', 'O'),
#   ('integrating', 'O'),
#   ('the', 'O'),
#   ('advantages', 'O'),
#   ('of', 'O'),
#   ('phrase', 'B'),
#   ('-', 'I'),
#   ('based', 'I'),
#   ('and', 'O'),
#   ('syntax', 'B'),
#   ('-', 'I'),
#   ('based', 'I'),
#   ('translation', 'I'),
#   ('.', 'O')],
#  [('We', 'O'),
#   ('report', 'O'),
#   ('statistically', 'O'),
#   ('significant', 'O'),
#   ('improvements', 'O'),
#   ('over', 'O'),
#   ('a', 'O'),
#   ('phrase', 'B'),
#   ('-', 'I'),
#   ('based', 'I'),
#   ('baseline', 'I'),
#   ('on', 'O'),
#   ('five', 'O'),
#   ('of', 'O'),
#   ('seven', 'O'),
#   ('test', 'O'),
#   ('sets', 'O'),
#   ('across', 'O'),
#   ('four', 'O'),
#   ('language', 'B'),
#   ('pairs', 'I'),
#   ('.', 'O')],
#  [('We', 'O'),
#   ('also', 'O'),
#   ('present', 'O'),
#   ('encouraging', 'O'),
#   ('preliminary', 'O'),
#   ('results', 'O'),
#   ('on', 'O'),
#   ('the', 'O'),
#   ('use', 'O'),
#   ('of', 'O'),
#   ('unsupervised', 'B'),
#   ('dependency', 'I'),
#   ('parsing', 'I'),
#   ('for', 'O'),
#   ('syntax', 'B'),
#   ('-', 'I'),
#   ('based', 'I'),
#   ('machine', 'I'),
#   ('translation', 'I'),
#   ('.', 'O')],
#  [('The', 'O'),
#   ('written', 'O'),
#   ('form', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('Arabic', 'B'),
#   ('language', 'I'),
#   (',', 'O'),
#   ('Modern', 'B'),
#   ('Standard', 'I'),
#   ('Arabic', 'I'),
#   ('(', 'O'),
#   ('MSA', 'B'),
#   (')', 'O'),
#   (',', 'O'),
#   ('differs', 'O'),
#   ('in', 'O'),
#   ('a', 'O'),
#   ('non', 'O'),
#   ('-', 'O'),
#   ('trivial', 'O'),
#   ('manner', 'O'),
#   ('from', 'O'),
#   ('the', 'O'),
#   ('various', 'O'),
#   ('spoken', 'B'),
#   ('regional', 'I'),
#   ('dialects', 'I'),
#   ('of', 'O'),
#   ('Arabic', 'B'),
#   ('—', 'O'),
#   ('the', 'O'),
#   ('true', 'O'),
#   ('“', 'O'),
#   ('native', 'B'),
#   ('languages', 'B'),
#   ('”', 'O'),
#   ('of', 'O'),
#   ('Arabic', 'B'),
#   ('speakers', 'I'),
#   ('.', 'O')],
#  [('Those', 'O'),
#   ('dialects', 'O'),
#   (',', 'O'),
#   ('in', 'O'),
#   ('turn', 'O'),
#   (',', 'O'),
#   ('differ', 'O'),
#   ('quite', 'O'),
#   ('a', 'O'),
#   ('bit', 'O'),
#   ('from', 'O'),
#   ('each', 'O'),
#   ('other', 'O'),
#   ('.', 'O')],
#  [('However', 'O'),
#   (',', 'O'),
#   ('due', 'O'),
#   ('to', 'O'),
#   ('MSA', 'B'),
#   ("'s", 'O'),
#   ('prevalence', 'O'),
#   ('in', 'O'),
#   ('written', 'B'),
#   ('form', 'I'),
#   (',', 'O'),
#   ('almost', 'O'),
#   ('all', 'O'),
#   ('Arabic', 'B'),
#   ('data', 'B'),
#   ('sets', 'I'),
#   ('have', 'O'),
#   ('predominantly', 'O'),
#   ('MSA', 'B'),
#   ('content', 'O'),
#   ('.', 'O')],
#  [('In', 'O'),
#   ('this', 'O'),
#   ('article', 'O'),
#   (',', 'O'),
#   ('we', 'O'),
#   ('describe', 'O'),
#   ('the', 'O'),
#   ('creation', 'O'),
#   ('of', 'O'),
#   ('a', 'O'),
#   ('novel', 'O'),
#   ('Arabic', 'B'),
#   ('resource', 'O'),
#   ('with', 'O'),
#   ('dialect', 'B'),
#   ('annotations', 'B'),
#   ('.', 'O')],
#  [('We', 'O'),
#   ('have', 'O'),
#   ('created', 'O'),
#   ('a', 'O'),
#   ('large', 'O'),
#   ('monolingual', 'B'),
#   ('data', 'I'),
#   ('set', 'I'),
#   ('rich', 'O'),
#   ('in', 'O'),
#   ('dialectal', 'B'),
#   ('Arabic', 'B'),
#   ('content', 'O'),
#   ('called', 'O'),
#   ('the', 'O'),
#   ('Arabic', 'B'),
#   ('On', 'I'),
#   ('-', 'I'),
#   ('line', 'I'),
#   ('Commentary', 'I'),
#   ('Data', 'B'),
#   ('set', 'I'),
#   ('(', 'O'),
#   ('Zaidan', 'O'),
#   ('and', 'O'),
#   ('Callison', 'O'),
#   ('-', 'O'),
#   ('Burch', 'O'),
#   ('2011', 'O'),
#   (')', 'O'),
#   ('.', 'O')],
#  [('We', 'O'),
#   ('describe', 'O'),
#   ('our', 'O'),
#   ('annotation', 'B'),
#   ('effort', 'O'),
#   ('to', 'O'),
#   ('identify', 'O'),
#   ('the', 'O'),
#   ('dialect', 'B'),
#   ('level', 'I'),
#   ('(', 'O'),
#   ('and', 'O'),
#   ('dialect', 'B'),
#   ('itself', 'O'),
#   (')', 'O'),
#   ('in', 'O'),
#   ('each', 'O'),
#   ('of', 'O'),
#   ('more', 'O'),
#   ('than', 'O'),
#   ('100000', 'O'),
#   ('sentences', 'B'),
#   ('from', 'O'),
#   ('the', 'O'),
#   ('data', 'B'),
#   ('set', 'O'),
#   ('by', 'O'),
#   ('crowdsourcing', 'B'),
#   ('the', 'O'),
#   ('annotation', 'B'),
#   ('task', 'I'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('delve', 'O'),
#   ('into', 'O'),
#   ('interesting', 'O'),
#   ('annotator', 'B'),
#   ('behaviors', 'O'),
#   ('(', 'O'),
#   ('like', 'O'),
#   ('over', 'O'),
#   ('-', 'O'),
#   ('identification', 'B'),
#   ('of', 'O'),
#   ('one', 'O'),
#   ("'s", 'O'),
#   ('own', 'O'),
#   ('dialect', 'B'),
#   (')', 'O'),
#   ('.', 'O')],
#  [('Using', 'O'),
#   ('this', 'O'),
#   ('new', 'O'),
#   ('annotated', 'B'),
#   ('data', 'B'),
#   ('set', 'I'),
#   (',', 'O'),
#   ('we', 'O'),
#   ('consider', 'O'),
#   ('the', 'O'),
#   ('task', 'O'),
#   ('of', 'O'),
#   ('Arabic', 'B'),
#   ('dialect', 'I'),
#   ('identification', 'I'),
#   (':', 'O'),
#   ('Given', 'O'),
#   ('the', 'O'),
#   ('word', 'B'),
#   ('sequence', 'B'),
#   ('forming', 'O'),
#   ('an', 'O'),
#   ('Arabic', 'B'),
#   ('sentence', 'B'),
#   (',', 'O'),
#   ('determine', 'O'),
#   ('the', 'O'),
#   ('variety', 'O'),
#   ('of', 'O'),
#   ('Arabic', 'B'),
#   ('in', 'O'),
#   ('which', 'O'),
#   ('it', 'O'),
#   ('is', 'O'),
#   ('written', 'O'),
#   ('.', 'O')],
#  [('We', 'O'),
#   ('use', 'O'),
#   ('the', 'O'),
#   ('data', 'B'),
#   ('to', 'O'),
#   ('train', 'B'),
#   ('and', 'O'),
#   ('evaluate', 'B'),
#   ('automatic', 'B'),
#   ('classifiers', 'I'),
#   ('for', 'O'),
#   ('dialect', 'B'),
#   ('identification', 'I'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('establish', 'O'),
#   ('that', 'O'),
#   ('classifiers', 'B'),
#   ('using', 'O'),
#   ('dialectal', 'B'),
#   ('data', 'B'),
#   ('significantly', 'O'),
#   ('and', 'O'),
#   ('dramatically', 'O'),
#   ('outperform', 'O'),
#   ('baselines', 'O'),
#   ('that', 'O'),
#   ('use', 'O'),
#   ('MSA', 'B'),
#   ('-', 'O'),
#   ('only', 'O'),
#   ('data', 'B'),
#   (',', 'O'),
#   ('achieving', 'O'),
#   ('near', 'O'),
#   ('-', 'O'),
#   ('human', 'O'),
#   ('classification', 'B'),
#   ('accuracy', 'B'),
#   ('.', 'O')],
#  [('Finally', 'O'),
#   (',', 'O'),
#   ('we', 'O'),
#   ('apply', 'O'),
#   ('our', 'O'),
#   ('classifiers', 'B'),
#   ('to', 'O'),
#   ('discover', 'O'),
#   ('dialectical', 'B'),
#   ('data', 'I'),
#   ('from', 'O'),
#   ('a', 'O'),
#   ('large', 'O'),
#   ('Web', 'B'),
#   ('crawl', 'I'),
#   ('consisting', 'O'),
#   ('of', 'O'),
#   ('3.5', 'O'),
#   ('million', 'O'),
#   ('pages', 'O'),
#   ('mined', 'O'),
#   ('from', 'O'),
#   ('on', 'O'),
#   ('-', 'O'),
#   ('line', 'O'),
#   ('Arabic', 'B'),
#   ('newspapers', 'O'),
#   ('.', 'O')],
#  [('Finding', 'O'),
#   ('the', 'O'),
#   ('right', 'O'),
#   ('representations', 'O'),
#   ('for', 'O'),
#   ('words', 'B'),
#   ('is', 'O'),
#   ('critical', 'O'),
#   ('for', 'O'),
#   ('building', 'O'),
#   ('accurate', 'O'),
#   ('NLP', 'B'),
#   ('systems', 'I'),
#   ('when', 'O'),
#   ('domain', 'O'),
#   ('-', 'O'),
#   ('specific', 'O'),
#   ('labeled', 'B'),
#   ('data', 'B'),
#   ('for', 'O'),
#   ('the', 'O'),
#   ('task', 'B'),
#   ('is', 'O'),
#   ('scarce', 'O'),
#   ('.', 'O')],
#  [('This', 'O'),
#   ('article', 'O'),
#   ('investigates', 'O'),
#   ('novel', 'O'),
#   ('techniques', 'O'),
#   ('for', 'O'),
#   ('extracting', 'B'),
#   ('features', 'I'),
#   ('from', 'O'),
#   ('n', 'B'),
#   ('-', 'I'),
#   ('gram', 'I'),
#   ('models', 'O'),
#   (',', 'O'),
#   ('Hidden', 'B'),
#   ('Markov', 'I'),
#   ('Models', 'I'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('other', 'O'),
#   ('statistical', 'B'),
#   ('language', 'I'),
#   ('models', 'I'),
#   (',', 'O'),
#   ('including', 'O'),
#   ('a', 'O'),
#   ('novel', 'O'),
#   ('Partial', 'O'),
#   ('Lattice', 'B'),
#   ('Markov', 'I'),
#   ('Random', 'I'),
#   ('Field', 'I'),
#   ('model', 'I'),
#   ('.', 'O')],
#  [('Experiments', 'B'),
#   ('on', 'O'),
#   ('part', 'O'),
#   ('-', 'O'),
#   ('of', 'O'),
#   ('-', 'O'),
#   ('speech', 'B'),
#   ('tagging', 'I'),
#   ('and', 'O'),
#   ('information', 'B'),
#   ('extraction', 'I'),
#   (',', 'O'),
#   ('among', 'O'),
#   ('other', 'O'),
#   ('tasks', 'O'),
#   (',', 'O'),
#   ('indicate', 'O'),
#   ('that', 'O'),
#   ('features', 'B'),
#   ('taken', 'O'),
#   ('from', 'O'),
#   ('statistical', 'B'),
#   ('language', 'I'),
#   ('models', 'I'),
#   (',', 'O'),
#   ('in', 'O'),
#   ('combination', 'O'),
#   ('with', 'O'),
#   ('more', 'O'),
#   ('traditional', 'B'),
#   ('features', 'I'),
#   (',', 'O'),
#   ('outperform', 'O'),
#   ('traditional', 'O'),
#   ('representations', 'B'),
#   ('alone', 'O'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('that', 'O'),
#   ('graphical', 'B'),
#   ('model', 'I'),
#   ('representations', 'I'),
#   ('outperform', 'O'),
#   ('n', 'B'),
#   ('-', 'I'),
#   ('gram', 'I'),
#   ('models', 'I'),
#   (',', 'O'),
#   ('especially', 'O'),
#   ('on', 'O'),
#   ('sparse', 'B'),
#   ('and', 'I'),
#   ('polysemous', 'I'),
#   ('words', 'I'),
#   ('.', 'O')],
#  [('What', 'O'),
#   ('is', 'O'),
#   ('here', 'O'),
#   ('called', 'O'),
#   ('controlled', 'B'),
#   ('natural', 'I'),
#   ('language', 'I'),
#   ('(', 'O'),
#   ('CNL', 'B'),
#   (')', 'O'),
#   ('has', 'O'),
#   ('traditionally', 'O'),
#   ('been', 'O'),
#   ('given', 'O'),
#   ('many', 'O'),
#   ('different', 'O'),
#   ('names', 'O'),
#   ('.', 'O')],
#  [('Especially', 'O'),
#   ('during', 'O'),
#   ('the', 'O'),
#   ('last', 'O'),
#   ('four', 'O'),
#   ('decades', 'O'),
#   (',', 'O'),
#   ('a', 'O'),
#   ('wide', 'O'),
#   ('variety', 'O'),
#   ('of', 'O'),
#   ('such', 'O'),
#   ('languages', 'B'),
#   ('have', 'O'),
# ...
#   ('error', 'O'),
#   ('reduction', 'O'),
#   ('of', 'O'),
#   ('18', 'O'),
#   ('%', 'O'),
#   ('in', 'O'),
#   ('total', 'O'),
#   ('over', 'O'),
#   ('state', 'O'),
#   ('-', 'O'),
#   ('of', 'O'),
#   ('-', 'O'),
#   ('the', 'O'),
#   ('-', 'O'),
#   ('art', 'O'),
#   ('baselines', 'O'),
#   ('.', 'O')],
#  [('Despite', 'O'),
#   ('the', 'O'),
#   ('effectiveness', 'O'),
#   ('to', 'O'),
#   ('boost', 'O'),
#   ('accuracy', 'O'),
#   (',', 'O'),
#   ('computationally', 'B'),
#   ('expensive', 'I'),
#   ('parsers', 'I'),
#   ('make', 'O'),
#   ('hybrid', 'O'),
#   ('systems', 'O'),
#   ('inappropriate', 'O'),
#   ('for', 'O'),
#   ('many', 'O'),
#   ('realistic', 'O'),
#   ('NLP', 'B'),
#   ('applications', 'O'),
#   ('.', 'O')],
#  [('In', 'O'),
#   ('this', 'O'),
#   ('article', 'O'),
#   (',', 'O'),
#   ('we', 'O'),
#   ('are', 'O'),
#   ('also', 'O'),
#   ('concerned', 'O'),
#   ('with', 'O'),
#   ('improving', 'O'),
#   ('tagging', 'B'),
#   ('efficiency', 'I'),
#   ('at', 'O'),
#   ('test', 'B'),
#   ('time', 'I'),
#   ('.', 'O')],
#  [('In', 'O'),
#   ('particular', 'O'),
#   (',', 'O'),
#   ('we', 'O'),
#   ('explore', 'O'),
#   ('unlabeled', 'B'),
#   ('data', 'I'),
#   ('to', 'O'),
#   ('transfer', 'O'),
#   ('the', 'O'),
#   ('predictive', 'O'),
#   ('power', 'O'),
#   ('of', 'O'),
#   ('hybrid', 'O'),
#   ('models', 'O'),
#   ('to', 'O'),
#   ('simple', 'B'),
#   ('sequence', 'I'),
#   ('models', 'I'),
#   ('.', 'O')],
#  [('Specifically', 'O'),
#   (',', 'O'),
#   ('hybrid', 'B'),
#   ('systems', 'I'),
#   ('are', 'O'),
#   ('utilized', 'O'),
#   ('to', 'O'),
#   ('create', 'O'),
#   ('large', 'O'),
#   ('-', 'O'),
#   ('scale', 'O'),
#   ('pseudo', 'O'),
#   ('training', 'O'),
#   ('data', 'O'),
#   ('for', 'O'),
#   ('cheap', 'O'),
#   ('models', 'O'),
#   ('.', 'O')],
#  [('Experimental', 'O'),
#   ('results', 'O'),
#   ('illustrate', 'O'),
#   ('that', 'O'),
#   ('the', 'O'),
#   ('re', 'O'),
#   ('-', 'O'),
#   ('compiled', 'O'),
#   ('models', 'O'),
#   ('not', 'O'),
#   ('only', 'O'),
#   ('achieve', 'O'),
#   ('high', 'O'),
#   ('accuracy', 'O'),
#   ('with', 'O'),
#   ('respect', 'O'),
#   ('to', 'O'),
#   ('per', 'O'),
#   ('token', 'O'),
#   ('classification', 'O'),
#   (',', 'O'),
#   ('but', 'O'),
#   ('also', 'O'),
#   ('serve', 'O'),
#   ('as', 'O'),
#   ('a', 'O'),
#   ('front', 'B'),
#   ('-', 'I'),
#   ('end', 'I'),
#   ('to', 'O'),
#   ('a', 'O'),
#   ('parser', 'O'),
#   ('well', 'O'),
#   ('.', 'O')],
#  [('Microblogs', 'B'),
#   ('such', 'O'),
#   ('as', 'O'),
#   ('Twitter', 'O'),
#   (',', 'O'),
#   ('Facebook', 'O'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('Sina', 'O'),
#   ('Weibo', 'O'),
#   ('(', 'O'),
#   ('China', 'O'),
#   ("'s", 'O'),
#   ('equivalent', 'O'),
#   ('of', 'O'),
#   ('Twitter', 'O'),
#   (')', 'O'),
#   ('are', 'O'),
#   ('a', 'O'),
#   ('remarkable', 'O'),
#   ('linguistic', 'B'),
#   ('resource', 'O'),
#   ('.', 'O')],
#  [('In', 'O'),
#   ('contrast', 'O'),
#   ('to', 'O'),
#   ('content', 'O'),
#   ('from', 'O'),
#   ('edited', 'O'),
#   ('genres', 'O'),
#   ('such', 'O'),
#   ('as', 'O'),
#   ('newswire', 'B'),
#   (',', 'O'),
#   ('microblogs', 'B'),
#   ('contain', 'O'),
#   ('discussions', 'O'),
#   ('of', 'O'),
#   ('virtually', 'O'),
#   ('every', 'O'),
#   ('topic', 'O'),
#   ('by', 'O'),
#   ('numerous', 'O'),
#   ('individuals', 'O'),
#   ('in', 'O'),
#   ('different', 'O'),
#   ('languages', 'O'),
#   ('and', 'O'),
#   ('dialects', 'B'),
#   ('and', 'O'),
#   ('in', 'O'),
#   ('different', 'O'),
#   ('styles', 'O'),
#   ('.', 'O')],
#  [('In', 'O'),
#   ('this', 'O'),
#   ('work', 'O'),
#   (',', 'O'),
#   ('we', 'O'),
#   ('show', 'O'),
#   ('that', 'O'),
#   ('some', 'O'),
#   ('microblog', 'B'),
#   ('users', 'O'),
#   ('post', 'O'),
#   ('“', 'B'),
#   ('self', 'I'),
#   ('-', 'I'),
#   ('translated', 'I'),
#   ('”', 'I'),
#   ('messages', 'O'),
#   ('targeting', 'O'),
#   ('audiences', 'O'),
#   ('who', 'O'),
#   ('speak', 'O'),
#   ('different', 'O'),
#   ('languages', 'O'),
#   (',', 'O'),
#   ('either', 'O'),
#   ('by', 'O'),
#   ('writing', 'O'),
#   ('the', 'O'),
#   ('same', 'O'),
#   ('message', 'O'),
#   ('in', 'O'),
#   ('multiple', 'O'),
#   ('languages', 'O'),
#   ('or', 'O'),
#   ('by', 'O'),
#   ('retweeting', 'O'),
#   ('translations', 'O'),
#   ('of', 'O'),
#   ('their', 'O'),
#   ('original', 'O'),
#   ('posts', 'O'),
#   ('in', 'O'),
#   ('a', 'O'),
#   ('second', 'O'),
#   ('language', 'O'),
#   ('.', 'O')],
#  [('We', 'O'),
#   ('introduce', 'O'),
#   ('a', 'O'),
#   ('method', 'O'),
#   ('for', 'O'),
#   ('finding', 'O'),
#   ('and', 'O'),
#   ('extracting', 'O'),
#   ('this', 'O'),
#   ('naturally', 'B'),
#   ('occurring', 'I'),
#   ('parallel', 'I'),
#   ('data', 'I'),
#   ('.', 'O')],
#  [('Identifying', 'O'),
#   ('the', 'O'),
#   ('parallel', 'O'),
#   ('content', 'O'),
#   ('requires', 'O'),
#   ('solving', 'O'),
#   ('an', 'O'),
#   ('alignment', 'B'),
#   ('problem', 'I'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('we', 'O'),
#   ('give', 'O'),
#   ('an', 'O'),
#   ('optimally', 'O'),
#   ('efficient', 'O'),
#   ('dynamic', 'B'),
#   ('programming', 'I'),
#   ('algorithm', 'I'),
#   ('for', 'O'),
#   ('this', 'O'),
#   ('.', 'O')],
#  [('Using', 'O'),
#   ('our', 'O'),
#   ('method', 'O'),
#   (',', 'O'),
#   ('we', 'O'),
#   ('extract', 'O'),
#   ('nearly', 'O'),
#   ('3', 'O'),
#   ('M', 'O'),
#   ('Chinese', 'O'),
#   ('–', 'O'),
#   ('English', 'O'),
#   ('parallel', 'B'),
#   ('segments', 'I'),
#   ('from', 'O'),
#   ('Sina', 'O'),
#   ('Weibo', 'O'),
#   ('using', 'O'),
#   ('a', 'O'),
#   ('targeted', 'O'),
#   ('crawl', 'O'),
#   ('of', 'O'),
#   ('Weibo', 'O'),
#   ('users', 'O'),
#   ('who', 'O'),
#   ('post', 'O'),
#   ('in', 'O'),
#   ('multiple', 'O'),
#   ('languages', 'O'),
#   ('.', 'O')],
#  [('Additionally', 'O'),
#   (',', 'O'),
#   ('from', 'O'),
#   ('a', 'O'),
#   ('random', 'O'),
#   ('sample', 'O'),
#   ('of', 'O'),
#   ('Twitter', 'O'),
#   (',', 'O'),
#   ('we', 'O'),
#   ('obtain', 'O'),
#   ('substantial', 'O'),
#   ('amounts', 'O'),
#   ('of', 'O'),
#   ('parallel', 'B'),
#   ('data', 'I'),
#   ('in', 'O'),
#   ('multiple', 'O'),
#   ('language', 'B'),
#   ('pairs', 'I'),
#   ('.', 'O')],
#  [('Evaluation', 'O'),
#   ('is', 'O'),
#   ('performed', 'O'),
#   ('by', 'O'),
#   ('assessing', 'O'),
#   ('the', 'O'),
#   ('accuracy', 'O'),
#   ('of', 'O'),
#   ('our', 'O'),
#   ('extraction', 'O'),
#   ('approach', 'O'),
#   ('relative', 'O'),
#   ('to', 'O'),
#   ('a', 'O'),
#   ('manual', 'B'),
#   ('annotation', 'I'),
#   ('as', 'O'),
#   ('well', 'O'),
#   ('as', 'O'),
#   ('in', 'O'),
#   ('terms', 'O'),
#   ('of', 'O'),
#   ('utility', 'O'),
#   ('as', 'O'),
#   ('training', 'B'),
#   ('data', 'I'),
#   ('for', 'O'),
#   ('a', 'O'),
#   ('Chinese', 'O'),
#   ('–', 'O'),
#   ('English', 'O'),
#   ('machine', 'B'),
#   ('translation', 'I'),
#   ('system', 'I'),
#   ('.', 'O')],
#  [('Relative', 'O'),
#   ('to', 'O'),
#   ('traditional', 'O'),
#   ('parallel', 'B'),
#   ('data', 'I'),
#   ('resources', 'I'),
#   (',', 'O'),
#   ('the', 'O'),
#   ('automatically', 'O'),
#   ('extracted', 'O'),
#   ('parallel', 'B'),
#   ('data', 'I'),
#   ('yield', 'O'),
#   ('substantial', 'O'),
#   ('translation', 'B'),
#   ('quality', 'O'),
#   ('improvements', 'O'),
#   ('in', 'O'),
#   ('translating', 'O'),
#   ('microblog', 'B'),
#   ('text', 'O'),
#   ('and', 'O'),
#   ('modest', 'O'),
#   ('improvements', 'O'),
#   ('in', 'O'),
#   ('translating', 'O'),
#   ('edited', 'O'),
#   ('news', 'O'),
#   ('content', 'O'),
#   ('.', 'O')],
#  [('Word', 'B'),
#   ('sense', 'I'),
#   ('disambiguation', 'I'),
#   ('and', 'O'),
#   ('the', 'O'),
#   ('related', 'O'),
#   ('field', 'O'),
#   ('of', 'O'),
#   ('automated', 'B'),
#   ('word', 'I'),
#   ('sense', 'I'),
#   ('induction', 'I'),
#   ('traditionally', 'O'),
#   ('assume', 'O'),
#   ('that', 'O'),
#   ('the', 'O'),
#   ('occurrences', 'O'),
#   ('of', 'O'),
#   ('a', 'O'),
#   ('lemma', 'B'),
#   ('can', 'O'),
#   ('be', 'O'),
#   ('partitioned', 'O'),
#   ('into', 'O'),
#   ('senses', 'O'),
#   ('.', 'O')],
#  [('But', 'O'),
#   ('this', 'O'),
#   ('seems', 'O'),
#   ('to', 'O'),
#   ('be', 'O'),
#   ('a', 'O'),
#   ('much', 'O'),
#   ('easier', 'O'),
#   ('task', 'O'),
#   ('for', 'O'),
#   ('some', 'O'),
#   ('lemmas', 'B'),
#   ('than', 'O'),
#   ('others', 'O'),
#   ('.', 'O')],
#  [('Our', 'O'),
#   ('work', 'O'),
#   ('builds', 'O'),
#   ('on', 'O'),
#   ('recent', 'O'),
#   ('work', 'O'),
#   ('that', 'O'),
#   ('proposes', 'O'),
#   ('describing', 'O'),
#   ('word', 'O'),
#   ('meaning', 'O'),
#   ('in', 'O'),
#   ('a', 'O'),
#   ('graded', 'O'),
#   ('fashion', 'O'),
#   ('rather', 'O'),
#   ('than', 'O'),
#   ('through', 'O'),
#   ('a', 'O'),
#   ('strict', 'B'),
#   ('partition', 'I'),
#   ('into', 'O'),
#   ('senses', 'B'),
#   ('in', 'O'),
#   ('this', 'O'),
#   ('article', 'O'),
#   ('we', 'O'),
#   ('argue', 'O'),
#   ('that', 'O'),
#   ('not', 'O'),
#   ('all', 'O'),
#   ('lemmas', 'B'),
#   ('may', 'O'),
#   ('need', 'O'),
#   ('the', 'O'),
#   ('more', 'O'),
#   ('complex', 'O'),
#   ('graded', 'O'),
#   ('analysis', 'O'),
#   (',', 'O'),
#   ('depending', 'O'),
#   ('on', 'O'),
#   ('their', 'O'),
#   ('partitionability', 'B'),
#   ('.', 'O')],
#  [('Although', 'O'),
#   ('there', 'O'),
#   ('is', 'O'),
#   ('plenty', 'O'),
#   ('of', 'O'),
#   ('evidence', 'O'),
#   ('from', 'O'),
#   ('previous', 'O'),
#   ('studies', 'O'),
#   ('and', 'O'),
#   ('from', 'O'),
#   ('the', 'O'),
#   ('linguistics', 'O'),
#   ('literature', 'O'),
#   ('that', 'O'),
#   ('there', 'O'),
#   ('is', 'O'),
#   ('a', 'O'),
#   ('spectrum', 'B'),
#   ('of', 'I'),
#   ('partitionability', 'I'),
#   ('of', 'O'),
#   ('word', 'O'),
#   ('meanings', 'O'),
#   (',', 'O'),
#   ('this', 'O'),
#   ('is', 'O'),
#   ('the', 'O'),
#   ('first', 'O'),
#   ('attempt', 'O'),
#   ('to', 'O'),
#   ('measure', 'O'),
#   ('the', 'O'),
#   ('phenomenon', 'O'),
#   ('and', 'O'),
#   ('to', 'O'),
#   ('couple', 'O'),
#   ('the', 'O'),
#   ('machine', 'B'),
#   ('learning', 'I'),
#   ('literature', 'I'),
#   ('on', 'O'),
#   ('clusterability', 'B'),
#   ('with', 'O'),
#   ('word', 'O'),
#   ('usage', 'O'),
#   ('data', 'O'),
#   ('used', 'O'),
#   ('in', 'O'),
#   ('computational', 'B'),
#   ('linguistics', 'I'),
#   ('.', 'O')],
#  [('We', 'O'),
#   ('propose', 'O'),
#   ('to', 'O'),
#   ('operationalize', 'B'),
#   ('partitionability', 'I'),
#   ('as', 'O'),
#   ('clusterability', 'B'),
#   (',', 'O'),
#   ('a', 'O'),
#   ('measure', 'O'),
#   ('of', 'O'),
#   ('how', 'O'),
#   ('easy', 'O'),
#   ('the', 'O'),
#   ('occurrences', 'O'),
#   ('of', 'O'),
#   ('a', 'O'),
#   ('lemma', 'B'),
#   ('are', 'O'),
#   ('to', 'O'),
#   ('cluster', 'B'),
#   ('.', 'O')],
#  [('We', 'O'),
#   ('test', 'O'),
#   ('two', 'O'),
#   ('ways', 'O'),
#   ('of', 'O'),
#   ('measuring', 'O'),
#   ('clusterability', 'B'),
#   (':', 'O'),
#   ('(', 'O'),
#   ('1', 'O'),
#   (')', 'O'),
#   ('existing', 'O'),
#   ('measures', 'O'),
#   ('from', 'O'),
#   ('the', 'O'),
#   ('machine', 'B'),
#   ('learning', 'I'),
#   ('literature', 'I'),
#   ('that', 'O'),
#   ('aim', 'O'),
#   ('to', 'O'),
#   ('measure', 'O'),
#   ('the', 'O'),
#   ('goodness', 'B'),
#   ('of', 'I'),
#   ('optimal', 'I'),
#   ('k', 'I'),
#   ('-', 'I'),
#   ('means', 'I'),
#   ('clusterings', 'I'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('(', 'O'),
#   ('2', 'O'),
#   (')', 'O'),
#   ('the', 'O'),
#   ('idea', 'O'),
#   ('that', 'O'),
#   ('if', 'O'),
#   ('a', 'O'),
#   ('lemma', 'B'),
#   ('is', 'O'),
#   ('more', 'O'),
#   ('clusterable', 'B'),
#   (',', 'O'),
#   ('two', 'O'),
#   ('clusterings', 'B'),
#   ('based', 'O'),
#   ('on', 'O'),
#   ('two', 'O'),
#   ('different', 'O'),
#   ('“', 'O'),
#   ('views', 'O'),
#   ('”', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('same', 'O'),
#   ('data', 'O'),
#   ('points', 'O'),
#   ('will', 'O'),
#   ('be', 'O'),
#   ('more', 'O'),
#   ('congruent', 'B'),
#   ('.', 'O')],
#  [('The', 'O'),
#   ('two', 'O'),
#   ('views', 'O'),
#   ('that', 'O'),
#   ('we', 'O'),
#   ('use', 'O'),
#   ('are', 'O'),
#   ('two', 'O'),
#   ('different', 'O'),
#   ('sets', 'O'),
#   ('of', 'O'),
#   ('manually', 'B'),
#   ('constructed', 'I'),
#   ('lexical', 'I'),
#   ('substitutes', 'I'),
#   ('for', 'O'),
#   ('the', 'O'),
#   ('target', 'B'),
#   ('lemma', 'I'),
#   (',', 'O'),
#   ('on', 'O'),
#   ('the', 'O'),
#   ('one', 'O'),
#   ('hand', 'O'),
#   ('monolingual', 'B'),
#   ('paraphrases', 'I'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('on', 'O'),
#   ('the', 'O'),
#   ('other', 'O'),
#   ('hand', 'O'),
#   ('translations', 'B'),
#   ('.', 'O')],
#  [('We', 'O'),
#   ('apply', 'O'),
#   ('automatic', 'B'),
#   ('clustering', 'I'),
#   ('to', 'O'),
#   ('the', 'O'),
#   ('manual', 'B'),
#   ('annotations', 'I'),
#   ('.', 'O')],
#  [('We', 'O'),
#   ('use', 'O'),
#   ('manual', 'B'),
#   ('annotations', 'I'),
#   ('because', 'O'),
#   ('we', 'O'),
#   ('want', 'O'),
#   ('the', 'O'),
#   ('representations', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('instances', 'B'),
#   ('that', 'O'),
#   ('we', 'O'),
#   ('cluster', 'B'),
#   ('to', 'O'),
#   ('be', 'O'),
#   ('as', 'O'),
#   ('informative', 'B'),
#   ('and', 'O'),
#   ('“', 'O'),
#   ('clean', 'O'),
#   ('”', 'O'),
#   ('as', 'O'),
#   ('possible', 'O'),
#   ('.', 'O')],
#  [('We', 'O'),
#   ('show', 'O'),
#   ('that', 'O'),
#   ('when', 'O'),
#   ('we', 'O'),
#   ('control', 'O'),
#   ('for', 'O'),
#   ('polysemy', 'B'),
#   (',', 'O'),
#   ('our', 'O'),
#   ('measures', 'O'),
#   ('of', 'O'),
#   ('clusterability', 'B'),
#   ('tend', 'O'),
#   ('to', 'O'),
#   ('correlate', 'B'),
#   ('with', 'O'),
#   ('partitionability', 'B'),
#   (',', 'O'),
#   ('in', 'O'),
#   ('particular', 'O'),
#   ('some', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('type-(1', 'B'),
#   (')', 'I'),
#   ('clusterability', 'I'),
#   ('measures', 'I'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('that', 'O'),
#   ('these', 'O'),
#   ('measures', 'O'),
#   ('outperform', 'O'),
#   ('a', 'O'),
#   ('baseline', 'O'),
#   ('that', 'O'),
#   ('relies', 'O'),
#   ('on', 'O'),
#   ('the', 'O'),
#   ('amount', 'O'),
#   ('of', 'O'),
#   ('overlap', 'O'),
#   ('in', 'O'),
#   ('a', 'O'),
#   ('soft', 'B'),
#   ('clustering', 'I'),
#   ('.', 'O')],
#  [('This', 'O'),
#   ('article', 'O'),
#   ('presents', 'O'),
#   ('a', 'O'),
#   ('comparative', 'O'),
#   ('study', 'O'),
#   ('of', 'O'),
#   ('a', 'O'),
#   ('subfield', 'O'),
#   ('of', 'O'),
#   ('morphology', 'B'),
#   ('learning', 'I'),
#   ('referred', 'O'),
#   ('to', 'O'),
#   ('as', 'O'),
#   ('minimally', 'B'),
#   ('supervised', 'I'),
#   ('morphological', 'I'),
#   ('segmentation', 'I'),
#   ('.', 'O')],
#  [('In', 'O'),
#   ('morphological', 'B'),
#   ('segmentation', 'I'),
#   (',', 'O'),
#   ('word', 'B'),
#   ('forms', 'I'),
#   ('are', 'O'),
#   ('segmented', 'B'),
#   ('into', 'O'),
#   ('morphs', 'B'),
#   (',', 'O'),
#   ('the', 'O'),
#   ('surface', 'B'),
#   ('forms', 'I'),
#   ('of', 'O'),
#   ('morphemes', 'B'),
#   ('.', 'O')],
#  [('In', 'O'),
#   ('the', 'O'),
#   ('minimally', 'B'),
#   ('supervised', 'I'),
#   ('data', 'I'),
#   ('-', 'I'),
#   ('driven', 'I'),
#   ('learning', 'I'),
#   ('setting', 'I'),
#   (',', 'O'),
#   ('segmentation', 'B'),
#   ('models', 'I'),
#   ('are', 'O'),
#   ('learned', 'O'),
#   ('from', 'O'),
#   ('a', 'O'),
#   ('small', 'O'),
#   ('number', 'O'),
#   ('of', 'O'),
#   ('manually', 'B'),
#   ('annotated', 'I'),
#   ('word', 'O'),
#   ('forms', 'O'),
#   ('and', 'O'),
#   ('a', 'O'),
#   ('large', 'O'),
#   ('set', 'O'),
#   ('of', 'O'),
#   ('unannotated', 'B'),
#   ('word', 'O'),
#   ('forms', 'O'),
#   ('.', 'O')],
#  [('In', 'O'),
#   ('addition', 'O'),
#   ('to', 'O'),
#   ('providing', 'O'),
#   ('a', 'O'),
#   ('literature', 'O'),
#   ('survey', 'O'),
#   ('on', 'O'),
#   ('published', 'O'),
#   ('methods', 'O'),
#   (',', 'O'),
#   ('we', 'O'),
#   ('present', 'O'),
#   ('an', 'O'),
#   ('in', 'O'),
#   ('-', 'O'),
#   ('depth', 'O'),
#   ('empirical', 'O'),
#   ('comparison', 'O'),
#   ('on', 'O'),
#   ('three', 'O'),
#   ('diverse', 'O'),
#   ('model', 'B'),
#   ('families', 'I'),
#   (',', 'O'),
#   ('including', 'O'),
#   ('a', 'O'),
#   ('detailed', 'O'),
#   ('error', 'B'),
#   ('analysis', 'I'),
#   ('.', 'O')],
#  [('Based', 'O'),
#   ('on', 'O'),
#   ('the', 'O'),
#   ('literature', 'O'),
#   ('survey', 'O'),
#   (',', 'O'),
#   ('we', 'O'),
#   ('conclude', 'O'),
#   ('that', 'O'),
#   ('the', 'O'),
#   ('existing', 'O'),
#   ('methodology', 'O'),
#   ('contains', 'O'),
#   ('substantial', 'O'),
#   ('work', 'O'),
#   ('on', 'O'),
#   ('generative', 'B'),
#   ('morph', 'I'),
#   ('lexicon', 'I'),
#   ('-', 'O'),
#   ('based', 'O'),
#   ('approaches', 'O'),
#   ('and', 'O'),
#   ('methods', 'O'),
#   ('based', 'O'),
#   ('on', 'O'),
#   ('discriminative', 'B'),
#   ('boundary', 'I'),
#   ('detection', 'I'),
#   ('.', 'O')],
#  [('As', 'O'),
#   ('for', 'O'),
#   ('which', 'O'),
#   ('approach', 'O'),
#   ('has', 'O'),
#   ('been', 'O'),
#   ('more', 'O'),
#   ('successful', 'O'),
#   (',', 'O'),
#   ('both', 'O'),
#   ('the', 'O'),
#   ('previous', 'O'),
#   ('work', 'O'),
#   ('and', 'O'),
#   ('the', 'O'),
#   ('empirical', 'B'),
#   ('evaluation', 'I'),
#   ('presented', 'O'),
#   ('here', 'O'),
#   ('strongly', 'O'),
#   ('imply', 'O'),
#   ('that', 'O'),
#   ('the', 'O'),
#   ('current', 'O'),
#   ('state', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('art', 'O'),
#   ('is', 'O'),
#   ('yielded', 'O'),
#   ('by', 'O'),
#   ('the', 'O'),
#   ('discriminative', 'B'),
#   ('boundary', 'I'),
#   ('detection', 'I'),
#   ('methodology', 'I'),
#   ('.', 'O')]]

# %%
def word2features(sent, i):
    word = sent[i][0]
    
    features = {
        'bias': 1.0,
        'word.lower()': word.lower(),
        'word[-3:]': word[-3:],
        'word[-2:]': word[-2:],
        'word.isupper()': word.isupper(),
        'word.istitle()': word.istitle(),
        'word.isdigit()': word.isdigit(),      
    }
    if i > 0:
        word1 = sent[i-1][0]
        features.update({
            '-1:word.lower()': word1.lower(),
            '-1:word.istitle()': word1.istitle(),
            '-1:word.isupper()': word1.isupper(),
        })
    else:
        features['BOS'] = True
        
    if i < len(sent)-1:
        word1 = sent[i+1][0]
        features.update({
            '+1:word.lower()': word1.lower(),
            '+1:word.istitle()': word1.istitle(),
            '+1:word.isupper()': word1.isupper(),
        })
    else:
        features['EOS'] = True
                
    return features

# %%
def sent2features(sent):
    return [word2features(sent, i) for i in range(len(sent))]

def sent2labels(sent):
    return [label for token, label in sent]

def sent2tokens(sent):
    return [token for token, label in sent]

# %%
sent2features(train_sents[0])[0]
# Out:
# {'bias': 1.0,
#  'word.lower()': 'the',
#  'word[-3:]': 'The',
#  'word[-2:]': 'he',
#  'word.isupper()': False,
#  'word.istitle()': True,
#  'word.isdigit()': False,
#  'BOS': True,
#  '+1:word.lower()': 'most',
#  '+1:word.istitle()': False,
#  '+1:word.isupper()': False}

# %%
# %%time
X_train = [sent2features(s) for s in train_sents]
y_train = [sent2labels(s) for s in train_sents]

X_test = [sent2features(s) for s in test_sents]
y_test = [sent2labels(s) for s in test_sents]
# Out:
# CPU times: user 63.1 ms, sys: 3.46 ms, total: 66.6 ms
# Wall time: 64.7 ms

# %%
# %%time
crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs', 
    c1=0.1, 
    c2=0.1, 
    max_iterations=100, 
    all_possible_transitions=True
)
try:
    crf.fit(X_train, y_train)
except AttributeError:
    pass
predictions = crf.predict(X_test)
# Out:
# CPU times: user 679 ms, sys: 24.1 ms, total: 703 ms
# Wall time: 701 ms

# %% [markdown]
# ## Evaluation

# %%
# Evaluation with IBO tag
labels = list(crf.classes_)
labels.remove('O')
labels
# Out:
# ['B', 'I']

# %%
y_pred = crf.predict(X_test)
f1=round(metrics.flat_f1_score(y_test, y_pred, average='weighted', labels=labels),3)
acc=round(metrics.flat_accuracy_score(y_test,y_pred),3)
prec=round(metrics.flat_precision_score(y_test, y_pred,average='weighted'),3)
rec=round(metrics.flat_recall_score(y_test, y_pred,average='weighted'),3)

# %%
print(f'Accuracy:  {acc}\nPrecision: {prec}\nRecall:    {rec}\nF1-score:  {f1}')
# Out:
# Accuracy:  0.879
# Precision: 0.875
# Recall:    0.879
# F1-score:  0.723
